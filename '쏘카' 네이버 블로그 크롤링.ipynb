# %%
# https://kissi-pro.tistory.com/24

# %%
# 블로그 주소 가져오기 

from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote


results = []
for i in range(1,104):
    driver=webdriver.Chrome('C:/Users/kaitnam/Downloads/chromedriver_win32/chromedriver.exe')
    url=("https://section.blog.naver.com/Search/Post.naver?pageNo={}&rangeType=ALL&orderBy=sim&keyword=%EC%8F%98%EC%B9%B4%ED%94%8C%EB%9E%9C".format(i))
    driver.get(url)
    html=driver.page_source
    driver.close()

    soup = BeautifulSoup(html, 'html.parser')
    search = soup.findAll('div',{"class":"list_search_post"})

    for li in search:
        desc = li.find('div',{"class":"desc"})
        href = li.select('.desc_inner')[0]['href'][22:]
        results.append(href)
        print(href)
# Out:
# /chlgurwowkd/222522225478
# /iuni94007/222667206091
# /vivamayday/222514212671
# /gusdk9210/222598201805
# /indonesia2019/222576125801
# /woal3692/222492063029
# /kimhye0507/222537622165
# /mycream/222026035088
# /nsk432/222666296887
# /unique_vanue/222643504754
# /rmoneylee/222613493856
# /lefty72/222513964078
# /7tpwzd/222614312938
# /lazzys/221933929210
# /vivamayday/222336430844
# /gusdk9210/222544772235
# /bapymjh/222516603518
# /lyh2180/221921474880
# /benchoa23/222276695222
# /aikyo24/222503430180
# /mycream/222010832265
# /lovelyji816/222069467752
# /smonkeys/222112573572
# /y___ss/222366694385
# /lefty72/222400455282
# /dalkom83/222029984969
# /jinrocals/222582592949
# /gusdk9210/222564018894
# /vivamayday/222442602214
# /tearhunter/221910910923
# /en5942/222381710221
# /gjwldnjs0716/222327371807
# /purpleori/222194882245
# /gocarnet/222182091524
# /inlyh86/222199491267
# /dagamgi/222265652687
# /minjootopia/222107510098
# /begin22again/221982203845
# ...

# %%
print(results)
# Out:
# ['/chlgurwowkd/222522225478', '/iuni94007/222667206091', '/vivamayday/222514212671', '/gusdk9210/222598201805', '/indonesia2019/222576125801', '/woal3692/222492063029', '/kimhye0507/222537622165', '/mycream/222026035088', '/nsk432/222666296887', '/unique_vanue/222643504754', '/rmoneylee/222613493856', '/lefty72/222513964078', '/7tpwzd/222614312938', '/lazzys/221933929210', '/vivamayday/222336430844', '/gusdk9210/222544772235', '/bapymjh/222516603518', '/lyh2180/221921474880', '/benchoa23/222276695222', '/aikyo24/222503430180', '/mycream/222010832265', '/lovelyji816/222069467752', '/smonkeys/222112573572', '/y___ss/222366694385', '/lefty72/222400455282', '/dalkom83/222029984969', '/jinrocals/222582592949', '/gusdk9210/222564018894', '/vivamayday/222442602214', '/tearhunter/221910910923', '/en5942/222381710221', '/gjwldnjs0716/222327371807', '/purpleori/222194882245', '/gocarnet/222182091524', '/inlyh86/222199491267', '/dagamgi/222265652687', '/minjootopia/222107510098', '/begin22again
# ...

# %%
results = ['/chlgurwowkd/222522225478', '/iuni94007/222667206091', '/vivamayday/222514212671', '/gusdk9210/222598201805', '/indonesia2019/222576125801', '/woal3692/222492063029', '/kimhye0507/222537622165', '/mycream/222026035088', '/nsk432/222666296887', '/unique_vanue/222643504754', '/rmoneylee/222613493856', '/lefty72/222513964078', '/7tpwzd/222614312938', '/lazzys/221933929210', '/vivamayday/222336430844',
# %%
results_2 = results[74:130]

# %%
#iframe 제거 후 blog.naver.com 붙이기
def delete_iframe(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    src_url = "https://blog.naver.com/" + soup.iframe["src"]
    
    return src_url

# %%
def text_scraping(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    if soup.find("div", attrs={"class":"se-main-container"}):
        text = soup.find("div", attrs={"class":"se-main-container"}).get_text()
        text = text.replace("\n","") #공백 제거
        text = text.replace("\u200b","")
        return text
    else:
        return "확인불가"

# %%
urls = []
for i in

# %%
# 블로그 내용 가져오기 

from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote


driver=webdriver.Chrome('C:/Users/kaitnam/Downloads/chromedriver_win32/chromedriver.exe')
url=("https://blog.naver.com/iuni94007/222667206091")
driver.get(url)
html=driver.page_source
driver.close() 

soup = BeautifulSoup(html, 'html.parser')
search = soup.find('p',{"class":"se-text-paragraph.se-text-paragraph-align- "})

print(search)

# for li in search:
# desc = li.find('div',{"class":"desc"})
# href = li.select('.desc_inner')[0]['href'][22:]
# results.append(href)
# print(href)
# Out:
# None

# %%
#iframe 제거 후 blog.naver.com 붙이기
def delete_iframe(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    src_url = "https://blog.naver.com/" + soup.iframe["src"]
    
    return src_url

# %%
def text_scraping(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    if soup.find("div", attrs={"class":"se-main-container"}):
        text = soup.find("div", attrs={"class":"se-main-container"}).get_text()
        text = text.replace("\n","") #공백 제거
        text = text.replace("\u200b","")
        return text
    else:
        return "확인불가"

# %%
url2 = 'https://blog.naver.com//PostView.naver?blogId=iuni94007&logNo=222667206091&redirect=Dlog&widgetTypeCall=true&directAccess=false'
text_scraping(url2)
# Out:
# '이번글은 두달간 쏘카플랜 사용하면서 느낀 지극히 전문성없고 주관적인 후기입니다:)올해 초부터 에버랜드에서 일하게 됐다나이먹고 뭔 에버랜드 알바냐 할 수 있는데 사람 사귀고 즐기려는건 아니고 사육사가 되고싶어 경력도 쌓고 할겸 들어오게 된거다이 얘기는 나중에 다시 하기로하고 여튼 그래서 출퇴근에 쓸 차가 필요해졌다기숙사도 있고 통근차량도 있지만 내가 일하는 부서는 특성상 6시쯤에 일이 끝나는데 기숙사나 전대리에서는 퇴근이후에 할 수 있는게 없다. 그렇다고 통근버스는 출, 퇴근시간에 한대씩 있을 뿐더러 기다리는시간 통근버스로 타러가는시간 합하면 왕복 네시간은 생각해야해서 너무 시간이 아까웠다.그렇게 해서 차가 급하게 필요했고 중고차를 사기전에 쏘카플랜으로 렌트를 하게되었다. 내돈주고 빌린후기입니다!가입절차나 차량 받는과정 자체는 매우 간단했다어플로 진행하니 5분정도면 모든 과정이 완료 되었던것 같다간단하게 가입절차 살펴 보자면먼저 쏘카 어플을 설치한 후 하단에 보이는 플랜 버튼 눌러준다 맨아래 왼쪽끝!그럼 이런 화면이 뜨는데 여기서 본인이 원하는 차종을 선택해주면 된다.내가 차를 고른 기준은  딱 두가지인데1) 고속도로를 타야하니 경차를 제외한 차2) 그 외 최대한 싼차,,, (난 그지라,,) 화물차 옆 지나가면 흔들대던 스파크 ㅗㅜ..마침 제일 처음에 떠있는 아반떼 Ad 경차 제외하면 저게 제일 저렴했고 지금도 그렇다쏘카플랜용 차가 따로 있는게 아닌지라 연식도 좀 됐고 키로수도 꽤 나간다 키로수 쏘 헤비이제 계약 바로 진행하면기존쏘카와 달리 최소 한달 단위로 계약이 가능하다당연히 한달반 계약? 이런건 안된다또! 빌리는 기간이 길어질수록  달마다 빌리는금액은 줄어든다 (아마 6개월,1년 이렇게 가격 떨어지는거 같았다)하지만 난 한달만 타볼 생각이여서 일단 한달 결제 차량손해 면책은 제일 비싼거 하고 정비서비스는 고급형은 아직 할수도 없거니와 짧게 탄다면 무조건 기본형이 좋다이렇게 선택하고나면 예상 이용요금이 계산되어 나오는데 여기에 속지마라.. 아직 한발 남
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from pprint import pprint
import requests
import time
from urllib.parse import quote

driver=webdriver.Chrome('C:/Users/kaitnam/Downloads/chromedriver_win32/chromedriver.exe')
query = "쏘카플랜"
url = "https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=" + quote(query)
driver.get(url)
#html=driver.page_source
#driver.close()


results = []
# 수집할 게시물의 수
target = 10

for i in range(target):
    try:
        data = get_content(driver)
        results.append(data)
        move_next(driver)
    except:
        time.sleep(2)
        move_next(driver)

print(results)

#page1=[]
#soup = BeautifulSoup(html, 'html.parser')

#for li in soup.select('.list_search_post'): 
    #href = li.select('.desc_inner')[0].attrs['href'] 
    #print(href)

#a = soup.select("#content > section > div.area_list_search > div:nth-child(1) > div > div.info_post > div.desc > a.desc_inner")

#ul = soup.find('div',{"class":"list_search_post"})
#for i in ul:
    #a = i.find('a')
    #href = a.get_attribute('href')


#for lii in li:
    #a=lii.find('a')['onclick'].split("'")[1].split("'")[0]
    #page1.append(a)
    
#pprint(page1)
# Out:
# [['https://blog.naver.com/kimhye0507/222537622165'], ['https://blog.naver.com/trueloveu/222246878366'], ['https://blog.naver.com/trueloveu/222246878366'], ['https://blog.naver.com/trueloveu/222246878366'], ['https://blog.naver.com/trueloveu/222246878366'], ['https://blog.naver.com/trueloveu/222246878366'], ['https://blog.naver.com/trueloveu/222246878366'], ['https://blog.naver.com/trueloveu/222246878366'], ['https://blog.naver.com/trueloveu/222246878366'], ['https://blog.naver.com/trueloveu/222246878366']]

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from pprint import pprint
import requests
import time
from urllib.parse import quote

driver=webdriver.Chrome('C:/Users/kaitnam/Downloads/chromedriver_win32/chromedriver.exe')
query = "쏘카플랜"
url = "https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=" + quote(query)
driver.get(url)
html=driver.page_source
driver.close()

soup = BeautifulSoup(html, 'html.parser')

for li in soup.select('.list_search_post'): 
    href = li.select('.desc_inner')[0].attrs['href'][22:] 
    print(href)
# Out:
# /iuni94007/222667206091
# /chlgurwowkd/222522225478
# /vivamayday/222514212671
# /gusdk9210/222598201805
# /indonesia2019/222576125801
# /woal3692/222492063029
# /kimhye0507/222537622165

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote

query = "쏘카플랜"
url = "https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=" + quote(query)

# %%
#iframe 제거 후 blog.naver.com 붙이기
def delete_iframe(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    src_url = "https://blog.naver.com/" + soup.iframe["src"]
    
    return src_url

# %%
# 본문 스크래핑
def text_scraping(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    if soup.find("div", attrs={"class":"se-main-container"}):
        text = soup.find("div", attrs={"class":"se-main-container"}).get_text()
        text = text.replace("\n","") #공백 제거
        print("블로그")
        return text
    else:
        return "확인불가"

# %%
#resultss = ['/bill8964/221661375251','/ayoung916/221038534678','/kisspia/222292056766']
url = []
for i in results:    
    urls = ("https://blog.naver.com{}".format(i))
    url.append(urls)
    print(url)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
