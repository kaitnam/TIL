# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from pprint import pprint

url='https://ediya.com/contents/drink.html'
driver=webdriver.Chrome('C:/Users/kaitnam/Documents/PYTHON/chromedriver.exe')
driver.get(url)
html=driver.page_source
driver.close()

soup=BeautifulSoup(html, 'html.parser')


rank_list=soup.find(id="menu_ul")
rank_list_li=rank_list.findAll('span'[2])

for i in rank_list_li:
    print(i.text.strip())
# Out:
# 이디야 사과 & 당근 주스
#
# 이디야 비트 & 오렌지 주스
#
# 그린파인 후룻치노
#
# 블루코코 후룻치노
#
# 망고샤베트 빙수
#
# 바닐라쿠키 빙수
#
# 달고나 라떼
#
# 달고나 밀크티

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from pprint import pprint

url='https://ediya.com/contents/drink.html'
driver=webdriver.Chrome('C:/Users/kaitnam/Documents/PYTHON/chromedriver.exe')
driver.get(url)
html=driver.page_source
driver.close()

soup=BeautifulSoup(html, 'html.parser')

for span in soup.findAll('span'):
    span.decompose()

rank_list=soup.find(id="menu_ul")
rank_list_div=rank_list.findAll('div',{"class":"pro_detail"})



print(rank_list_div)
# Out:
# [<div class="pro_detail" id="nutri_382" style="display:none; ">
# <div class="detail_con">
# <h2>이디야 사과 &amp; 당근 주스                  </h2>
# <div class="detail_close"><a href="#c" onclick="hide_nutri('382')"><img alt="창닫기" height="16" src="/images/menu/pro_detail_close.gif" width="17"/></a></div>
# <p>은은한 당근향과 달콤한 사과의 맛이 어우러지는 진한 주황색 주스</p>
# </div>
# <div class="detail_sns"><!--
#                 	<a href="#c"><img src="../images/menu/pro_sns01.png" width="26" height="26" alt="페이스북" /></a>
#                   <a href="#c"><img src="../images/menu/pro_sns02.png" width="26" height="26" alt="인스타그램" /></a> -->
# </div>
# <div class="pro_comp">
# <!--pro_nutri div추가 180327-->
# <div class="pro_nutri">
# <dl>
# <dt>칼로리</dt>
# <dd>(103kcal)</dd>
# </dl>
# <dl>
# <dt> 당류</dt>
# <dd>(25g)</dd>
# </dl>
# <dl>
# <dt> 단백질</dt>
# <dd>(0g)</dd>
# </dl>
# <dl>
# <dt> 포화지방</dt>
# <dd>(0.0g)</dd>
# </dl>
# <dl>
# <dt> 나트륨</dt>
# <dd>(37mg)</dd>
# </dl>
# <dl>
# <dt> 카페인</dt>
# <dd>(0mg)</dd>
# ...

# %%
prod_cd = [[name['id'], name.find('h2').text.strip()] for name in rank_list_div]
pprint(prod_cd)
# Out:
# [['nutri_382', '이디야 사과 & 당근 주스'],
#  ['nutri_383', '이디야 비트 & 오렌지 주스'],
#  ['nutri_376', '그린파인 후룻치노'],
#  ['nutri_377', '블루코코 후룻치노'],
#  ['nutri_372', '망고샤베트 빙수'],
#  ['nutri_373', '바닐라쿠키 빙수'],
#  ['nutri_374', '달고나 라떼'],
#  ['nutri_375', '달고나 밀크티']]

# %%
import time
from selenium import webdriver

url = 'https://ediya.com/contents/drink.html'

driver = webdriver.Chrome('C:/Users/kaitnam/Documents/PYTHON/chromedriver.exe')
driver.get(url)

driver.implicitly_wait(5)

for page in range(1,21):


    if page == 1:
        pass
    
    else :
        elements = driver.find_element_by_xpath('//*[@id="contentWrap"]/div[5]/div/div/a')
        driver.execute_script("arguments[0].click();", elements)

    SCROLL_PAUSE_TIME = 2

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight-50);")
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")

        if new_height == last_height:
            break

        last_height = new_height
        
html=driver.page_source

soup=BeautifulSoup(html, 'html.parser')


result=[]

for el in soup.select('#menu_ul'):
    for i in range(0,8):
        asdf=el.select('li')[i]
            
        container=dict()
        name=asdf.findAll('a')[1].find('span').text
        kcal=asdf.select('dl')[0].find('dd').text
        sugars=asdf.select('dl')[1].find('dd').text
        protein=asdf.select('dl')[2].find('dd').text
        sat_FAT=asdf.select('dl')[3].find('dd').text
        sodium=asdf.select('dl')[4].find('dd').text
        caffeine=asdf.select('dl')[5].find('dd').text
            
        container['name']=name
        container['kcal']=kcal
        container['sugars']=sugars
        container['protein']=protein
        container['sat_FAT']=sat_FAT
        container['sodium']=sodium
        container['caffeine']=caffeine
            
        result.append(container)
    
    time.sleep(3)

pprint(result)
# Out:
# [{'caffeine': '(0mg)',
#   'kcal': '(103kcal)',
#   'name': '이디야 사과 & 당근 주스',
#   'protein': '(0g)',
#   'sat_FAT': '(0.0g)',
#   'sodium': '(37mg)',
#   'sugars': '(25g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(105kcal)',
#   'name': '이디야 비트 & 오렌지 주스',
#   'protein': '(3g)',
#   'sat_FAT': '(0.0g)',
#   'sodium': '(297mg)',
#   'sugars': '(19g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(283kcal)',
#   'name': '그린파인 후룻치노 ',
#   'protein': '(0g)',
#   'sat_FAT': '(0g)',
#   'sodium': '(33mg)',
#   'sugars': '(58g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(361kcal)',
#   'name': '블루코코 후룻치노    ',
#   'protein': '(7g)',
#   'sat_FAT': '(12.0g)',
#   'sodium': '(134mg)',
#   'sugars': '(34g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(592kcal)',
#   'name': '망고샤베트 빙수',
#   'protein': '(3g)',
#   'sat_FAT': '(1.8g)',
#   'sodium': '(65mg)',
#   'sugars': '(128g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(1263kcal)',
#   'name': '바닐라쿠키 빙수',
#   'protein': '(16g)',
#   'sat_FAT': '(40.0g)',
# ...

# %%
import time
from selenium import webdriver

url = 'https://ediya.com/contents/drink.html'

driver = webdriver.Chrome('C:/Users/kaitnam/Documents/PYTHON/chromedriver.exe')
driver.get(url)

driver.implicitly_wait(5)

for page in range(1,21):


    if page == 1:
        pass
    
    else :
        elements = driver.find_element_by_xpath('//*[@id="contentWrap"]/div[5]/div/div/a')
        driver.execute_script("arguments[0].click();", elements)

    SCROLL_PAUSE_TIME = 2

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight-50);")
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")

        if new_height == last_height:
            break

        last_height = new_height
        
html=driver.page_source

soup=BeautifulSoup(html, 'html.parser')


result=[]

for el in soup.select('#menu_ul'):
    for i in range(0,155):
        asdf=el.select('li')[i]
            
        container=dict()
        name=asdf.findAll('a')[1].find('span').text
        kcal=asdf.select('dl')[0].find('dd').text
        sugars=asdf.select('dl')[1].find('dd').text
        protein=asdf.select('dl')[2].find('dd').text
        sat_FAT=asdf.select('dl')[3].find('dd').text
        sodium=asdf.select('dl')[4].find('dd').text
        caffeine=asdf.select('dl')[5].find('dd').text
            
        container['name']=name
        container['kcal']=kcal
        container['sugars']=sugars
        container['protein']=protein
        container['sat_FAT']=sat_FAT
        container['sodium']=sodium
        container['caffeine']=caffeine
            
        result.append(container)
    
    time.sleep(3)

pprint(result)
# Out:
# [{'caffeine': '(0mg)',
#   'kcal': '(103kcal)',
#   'name': '이디야 사과 & 당근 주스',
#   'protein': '(0g)',
#   'sat_FAT': '(0.0g)',
#   'sodium': '(37mg)',
#   'sugars': '(25g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(105kcal)',
#   'name': '이디야 비트 & 오렌지 주스',
#   'protein': '(3g)',
#   'sat_FAT': '(0.0g)',
#   'sodium': '(297mg)',
#   'sugars': '(19g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(283kcal)',
#   'name': '그린파인 후룻치노 ',
#   'protein': '(0g)',
#   'sat_FAT': '(0g)',
#   'sodium': '(33mg)',
#   'sugars': '(58g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(361kcal)',
#   'name': '블루코코 후룻치노    ',
#   'protein': '(7g)',
#   'sat_FAT': '(12.0g)',
#   'sodium': '(134mg)',
#   'sugars': '(34g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(592kcal)',
#   'name': '망고샤베트 빙수',
#   'protein': '(3g)',
#   'sat_FAT': '(1.8g)',
#   'sodium': '(65mg)',
#   'sugars': '(128g)'},
#  {'caffeine': '(0mg)',
#   'kcal': '(1263kcal)',
#   'name': '바닐라쿠키 빙수',
#   'protein': '(16g)',
#   'sat_FAT': '(40.0g)',
# ...

# %%
import pandas as pd
df=pd.DataFrame(result)

df.to_excel("C:/Users/kaitnam/Documents/PYTHON/Project_CoffeeshopMenu/Ediya_Menu.xlsx", index=False)

df
# Out:
#                 name       kcal  sugars protein  sat_FAT   sodium caffeine
# 0     이디야 사과 & 당근 주스  (103kcal)   (25g)    (0g)   (0.0g)   (37mg)    (0mg)
# 1    이디야 비트 & 오렌지 주스  (105kcal)   (19g)    (3g)   (0.0g)  (297mg)    (0mg)
# 2         그린파인 후룻치노   (283kcal)   (58g)    (0g)     (0g)   (33mg)    (0mg)
# 3      블루코코 후룻치노      (361kcal)   (34g)    (7g)  (12.0g)  (134mg)    (0mg)
# 4           망고샤베트 빙수  (592kcal)  (128g)    (3g)   (1.8g)   (65mg)    (0mg)
# ..               ...        ...     ...     ...      ...      ...      ...
# 150           청포도에이드  (131kcal)   (30g)    (0g)     (0g)    (3mg)    (0mg)
# 151      (EX) 청포도에이드  (197kcal)   (45g)    (0g)     (0g)    (5mg)    (0mg)
# 152           눈꽃 팥빙수  (845kcal)   (65g)   (18g)   (5.0g)  (387mg)    (0mg)
# 153        눈꽃 애플망고빙수  (632kcal)  (120g)    (9g)   (4.3g)  (116mg)    (0mg)
# 154          눈꽃 초코빙수  (636kcal)   (67g)    (6g)  (20.0g)  (108mg)    (2mg)
#
# [155 rows x 7 columns]
