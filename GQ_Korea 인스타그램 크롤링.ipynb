# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from tqdm import tqdm

# %%
def insta_searching(word):
    url='https://www.instagram.com/'+word
    return url

# %%
from selenium.webdriver.common.by import By

def select_first(driver):
    # 웹페이지에 접속해서 첫번째 게시글 해당하는 tag 선택해줘
    first = driver.find_elements(By.CSS_SELECTOR,"div._aagw")[0]
    first.click()
    time.sleep(3)

# %%
def move_next(driver):
    right=driver.find_element(By.CSS_SELECTOR,'div._aaqg._aaqh')    
    right.click() 
    time.sleep(3)

# %%
import re
from bs4 import BeautifulSoup
import unicodedata   # 추가, 2020.08.20

def get_content(driver):
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')

    try: 
        # 본문내용
        content = soup.select('div._a9zs')[0].text
    except:
        content = ''

    # 해시태그
    tags = re.findall(r'#[^\s#,\\]+', content)  

    # 작성일자
    date = soup.select('time._aaqe')[0]['datetime'][:10]

    # 좋아요
    try:
        like = soup.select('div._aacl._aaco._aacw._aacx._aada._aade')[-1].text[3:-1]
    except:
        like = 0

    user_id = []
    comment = []
    try:
        ul = soup.find_all('ul','_a9ym')
        if len(ul) == 1:
            user_id = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
            comments = d.find('div','_a9zs').find('span').get_text().replace('\n',"").strip()
        else:
            for d in ul:
                user_idd = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
                comments = d.find('div','_a9zs').find('span').get_text().replace('\n',"").strip()
                user_id.append(user_idd)
                comment.append(comments)

    except:
        user_id = ''
        comments = ''
    
   
    data = [date, content,tags, user_id, comment, like]
    return data

# %%
# 인스타그램 접속하기
driver = webdriver.Chrome('C:/Users/katenam/chromedriver.exe')

driver.get("https://www.instagram.com/")
time.sleep(3)

# 인스타 아이디
id = "gfydkate"
# 비밀번호
pw = "dldlawkd3"

# id와 pw를 입력하는 창의 요소 정보 획득
input = driver.find_element(By.TAG_NAME, "input")

# 아이디를 입력
input[0].send_keys(id)

# 비밀번호 입력
input[1].send_keys(pw)

# 엔터
input[1].send_keys(Keys.RETURN)
time.sleep(5)

# 로그인 정보 저장 여부 ("나중에 하기 버튼 클릭")
btn_later1 = driver.find_element(By.CLASS_NAME, '_acan._acao._acas')
btn_later1.click()
time.sleep(5)

# 알림 설정 ("나중에 하기 버튼 클릭")
btn_later2 = driver.find_element(By.CLASS_NAME, '_a9--._a9_1')
btn_later2.click()


# 검색 결과 페이지 열기
word='gq_korea'
url=insta_searching(word)
driver.get(url)

time.sleep(10) #time.sleep(3) 설정했더니 에러남


# 첫 번째 게시물 클릭
select_first(driver)


# 본격적으로 데이터 수집 시작
results = []

# 수집할 게시물의 수
target = 3

for i in range(target):
    try:
        data = get_content(driver)
        results.append(data)
        move_next(driver)
    except:
        time.sleep(2)
        move_next(driver)
    time.sleep(5)

print(results)
# Out:
# []

# %%
import pandas as pd

results_1 = pd.DataFrame(results)
#result = results_df.transpose()
results_1.columns = ['date','content','tags','user_id','comment','like']
results_1

# %%
driver = webdriver.Chrome('C:/Users/katenam/chromedriver.exe')

driver.get("https://www.instagram.com/")

time.sleep(1)

# 인스타 아이디
id = "gfydkate"
# 비밀번호
pw = "dldlawkd3"

# id와 pw를 입력하는 창의 요소 정보 획득
input = driver.find_elements_by_tag_name("input")

# 아이디를 입력
input[0].send_keys(id)

# 비밀번호 입력
input[1].send_keys(pw)

# 엔터
input[1].send_keys(Keys.RETURN)
time.sleep(5)

# %%
# 인스타 아이디
id = "gfydkate"
# 비밀번호
pw = "dldlawkd3"

# id와 pw를 입력하는 창의 요소 정보 획득
input = driver.find_elements_by_tag_name("input")

# 아이디를 입력
input[0].send_keys(id)

# 비밀번호 입력
input[1].send_keys(pw)

# 엔터
input[1].send_keys(Keys.RETURN)
time.sleep(5)

# 로그인 정보 저장 여부 ("나중에 하기 버튼 클릭")
btn_later1 = driver.find_element_by_class_name('_acan._acao._acas')
btn_later1.click()
time.sleep(5)

# 알림 설정 ("나중에 하기 버튼 클릭")
btn_later2 = driver.find_element_by_class_name('_a9--._a9_1')
btn_later2.click()

# %%
# 로그인 정보 저장 여부 ("나중에 하기 버튼 클릭")
btn_later1 = driver.find_element_by_class_name('_acan._acao._acas')
btn_later1.click()
time.sleep(5)

# 알림 설정 ("나중에 하기 버튼 클릭")
btn_later2 = driver.find_element_by_class_name('_a9--._a9_1')
btn_later2.click()

# %%
import re
from bs4 import BeautifulSoup
import unicodedata   # 추가, 2020.08.20

def get_content(driver):
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')

    try: 
        # 본문내용
        content = soup.select('div._a9zs')[0].text
    except:
        content = ''

    # 해시태그
    tags = re.findall(r'#[^\s#,\\]+', content)  

    # 작성일자
    date = soup.select('time._aaqe')[0]['datetime'][:10]

    # 좋아요
    try:
        like = soup.select('div._aacl._aaco._aacw._aacx._aada._aade')[-1].text[3:-1]
    except:
        like = 0

    user_id = []
    comment = []
    try:
        ul = soup.find_all('ul','_a9ym')
        if len(ul) == 1:
            user_id = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
            comments = d.find('div','_a9zs').find('span').get_text().replace('\n',"").strip()
        else:
            for d in ul:
                user_idd = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
                comments = d.find('div','_a9zs').find('span').get_text().replace('\n',"").strip()
                user_id.append(user_idd)
                comment.append(comments)

    except:
        user_id = ''
        comments = ''
    
   
    data = [date, content,tags, user_id, comment, like]
    return data

# %%
import pandas as pd

results_df = pd.DataFrame(results)
#result = results_df.transpose()
results_df.columns = ['date','content','tags','user_id','comment','like']
results_df

# %%
def insta_searching(word):
    url='https://www.instagram.com/'+word
    return url

# %%
from selenium.webdriver.common.by import By

def select_first(driver):
    # 웹페이지에 접속해서 첫번째 게시글 해당하는 tag 선택해줘
    first = driver.find_elements_by_css_selector("div._aagw")[2]
    first.click()
    time.sleep(3)

# %%
import re
from bs4 import BeautifulSoup
import unicodedata   # 추가, 2020.08.20

def get_content(driver):
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
# 데이터 기록, 다음 게시물로 클릭
    try: 
        # 본문내용
        content = soup.select('div._a9zs')[0].text
    except:
        content = ''
    
    # 해시태그
    tags = re.findall(r'#[^\s#,\\]+', content)  
    
    # 작성일자
    date = soup.select('time._aaqe')[0]['datetime'][:10]
    
    # 좋아요
    try:
        like = soup.select('div._aacl._aaco._aacw._aacx._aada._aade')[0].findAll('span')[-1].text 
    except:
        like = 0
        
    # 댓글
#     try:
#         ul = soup.find_all('ul','_a9ym')
#         for d in ul:
#             user_id = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
#             comments = d.find('div','_a9zs').find_all('span')[1].get_text().replace('\n',"").strip()
#     except:
#         user_id = ''
#         comments = ''
   
    data = [date, content, tags, like]#, user_id, comments]
    return data

# %%
def move_next(driver):
    right=driver.find_element_by_css_selector('div._aaqg._aaqh')    
    right.click() 
    time.sleep(3)

# %%
# 인스타그램 접속하기
driver = webdriver.Chrome('C:/Users/katenam/chromedriver.exe')

driver.get("https://www.instagram.com/")
time.sleep(3)

# 인스타 아이디
id = "gfydkate"
# 비밀번호
pw = "dldlawkd3"

# id와 pw를 입력하는 창의 요소 정보 획득
input = driver.find_elements_by_tag_name("input")

# 아이디를 입력
input[0].send_keys(id)

# 비밀번호 입력
input[1].send_keys(pw)

# 엔터
input[1].send_keys(Keys.RETURN)
time.sleep(5)

# 로그인 정보 저장 여부 ("나중에 하기 버튼 클릭")
btn_later1 = driver.find_element_by_class_name('_acan._acao._acas')
btn_later1.click()
time.sleep(5)

# 알림 설정 ("나중에 하기 버튼 클릭")
btn_later2 = driver.find_element_by_class_name('_a9--._a9_1')
btn_later2.click()


# 검색 결과 페이지 열기
word='gq_korea'
url=insta_searching(word)
driver.get(url)

time.sleep(10) #time.sleep(3) 설정했더니 에러남


# 첫 번째 게시물 클릭
select_first(driver)

# 본격적으로 데이터 수집 시작
results = []

# 수집할 게시물의 수
target = 5

for i in range(target):
    try:
        data = get_content(driver)
        results.append(data)
        move_next(driver)
    except:
        time.sleep(2)
        move_next(driver)
    time.sleep(5)

print(results)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [22], in <cell line: 52>()
#      53 try:
# ---> 54     data = get_content(driver)
#      55     results.append(data)
#
# Input In [14], in get_content(driver)
#      18 # 작성일자
# ---> 19 date = soup.select('time._aaqe')[0]['datetime'][:10]
#      21 # 좋아요
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# Input In [22], in <cell line: 52>()
#      57     except:
#      58         time.sleep(2)
# ---> 59         move_next(driver)
#      60     time.sleep(5)
#      62 print(results)
#
# Input In [6], in move_next(driver)
#       1 def move_next(driver):
# ----> 2     right=driver.find_element_by_css_selector('div._aaqg._aaqh')
#       3     right.click()
#       4     time.sleep(3)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:598, in WebDriver.find_element_by_css_selector(self, css_selector)
#     582 def find_element_by_css_selector(self, css_selector):
#     583     """
#     584     Finds an element by css selector.
#     585
#    (...)
#     596         element = driver.find_element_by_css_selector('#foo')
#     597     """
# --> 598     return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div._aaqg._aaqh"}
#   (Session info: chrome=106.0.5249.91)

# %%
import re
from bs4 import BeautifulSoup
import unicodedata   # 추가, 2020.08.20

def get_content(driver):
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')

    try: 
        # 본문내용
        content = soup.select('div._a9zs')[0].text
    except:
        content = ''

    # 해시태그
    tags = re.findall(r'#[^\s#,\\]+', content)  

    # 작성일자
    date = soup.select('time._aaqe')[0]['datetime'][:10]

    # 좋아요
    try:
        like = soup.select('div._aacl._aaco._aacw._aacx._aada._aade')[-1].text[3:-1]
    except:
        like = 0

    user_id = []
    comment = []
    try:
        ul = soup.find_all('ul','_a9ym')
        if len(ul) == 1:
            user_id = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
            comments = d.find('div','_a9zs').find('span').get_text().replace('\n',"").strip()
        else:
            for d in ul:
                user_idd = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
                comments = d.find('div','_a9zs').find('span').get_text().replace('\n',"").strip()
                user_id.append(user_idd)
                comment.append(comments)

    except:
        user_id = ''
        comments = ''
    
   
    data = [date, content,tags, user_id, comment, like]
    return data

# %%
# 인스타그램 접속하기
driver = webdriver.Chrome('C:/Users/katenam/chromedriver.exe')

driver.get("https://www.instagram.com/")
time.sleep(3)

# 인스타 아이디
id = "gfydkate"
# 비밀번호
pw = "dldlawkd3"

driver.find_element(By.NAME,'username').send_keys(id)    # id 입력
elem_pw = driver.find_element(By.NAME,'password')    # pw 입력
elem_pw.send_keys(pw)
send = driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[3]')
send.click()

# # 인스타 아이디
# id = "gfydkate"
# # 비밀번호
# pw = "dldlawkd3"

# # id와 pw를 입력하는 창의 요소 정보 획득
# input = driver.find_elements(By.TAG_NAME,"input")

# # 아이디를 입력
# input[0].send_keys(id)

# # 비밀번호 입력
# input[1].send_keys(pw)

# # 엔터
# input[1].send_keys(Keys.RETURN)
# time.sleep(5)

# 로그인 정보 저장 여부 ("나중에 하기 버튼 클릭")
btn_later1 = driver.find_element(By.CLASS_NAME,'_acan._acao._acas')
btn_later1.click()
time.sleep(5)

# 알림 설정 ("나중에 하기 버튼 클릭")
btn_later2 = driver.find_element(By.CLASS_NAME,'_a9--._a9_1')
btn_later2.click()


# 검색 결과 페이지 열기
word='gq_korea'
url=insta_searching(word)
driver.get(url)

# time.sleep(10) #time.sleep(3) 설정했더니 에러남


# # 첫 번째 게시물 클릭
# select_first(driver)

# # 본격적으로 데이터 수집 시작
# results = []

# # 수집할 게시물의 수
# target = 5

# for i in range(target):

# # 데이터 기록, 다음 게시물로 클릭
#     html = driver.page_source
#     soup = BeautifulSoup(html, 'lxml')
#     try: 
#         # 본문내용
#         content = soup.select('div._a9zs')[0].text
#     except:
#         content = ''

#     # 해시태그
#     tags = re.findall(r'#[^\s#,\\]+', content)  

#     # 작성일자
#     date = soup.select('time._aaqe')[0]['datetime'][:10]

#     # 좋아요
#     try:
#         like = soup.select('div._aacl._aaco._aacw._aacx._aada._aade')[-1].text[3:-1]
#     except:
#         like = 0

#     user_id = []
#     comment = []
#     try:
#         ul = soup.find_all('ul','_a9ym')
#         if len(ul) == 1:
#             user_id = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
#             comments = d.find('div','_a9zs').find('span').get_text().replace('\n',"").strip()
#         else:
#             for d in ul:
#                 user_idd = d.find('h3','_a9zc').find('a').get_text().replace('\n',"").strip()
#                 comments = d.find('div','_a9zs').find('span').get_text().replace('\n',"").strip()
#                 user_id.append(user_idd)
#                 comment.append(comments)

#     except:
#         user_id = ''
#         comments = ''
    


# data = [date, content,tags, user_id, comment, like]
# print(data)
# Out:
# C:\Users\katenam\AppData\Local\Temp\ipykernel_31624\2383308796.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/katenam/chromedriver.exe')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [12], in <cell line: 42>()
#      39 time.sleep(5)
#      41 # 알림 설정 ("나중에 하기 버튼 클릭")
# ---> 42 btn_later2 = driver.find_element(By.CLASS_NAME,'_a9--._a9_1')
#      43 btn_later2.click()
#      46 # 검색 결과 페이지 열기
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"._a9--._a9_1"}
#   (Session info: chrome=108.0.5359.126)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00E8ACD3+2075859]
# 	Ordinal0 [0x00E1EE61+1633889]
# 	Ordinal0 [0x00D1B7BD+571325]
# 	Ordinal0 [0x00D4AC2F+764975]
# 	Ordinal0 [0x00D4AE1B+765467]
# 	Ordinal0 [0x00D7D0F2+970994]
# 	Ordinal0 [0x00D67364+881508]
# 	Ordinal0 [0x00D7B56A+963946]
# 	Ordinal0 [0x00D67136+880950]
# 	Ordinal0 [0x00D3FEFD+720637]
# 	Ordinal0 [0x00D40F3F+724799]
# 	GetHandleVerifier [0x0113EED2+2769538]
# 	GetHandleVerifier [0x01130D95+2711877]
# 	GetHandleVerifier [0x00F1A03A+521194]
# 	GetHandleVerifier [0x00F18DA0+516432]
# 	Ordinal0 [0x00E2682C+1665068]
# 	Ordinal0 [0x00E2B128+1683752]
# 	Ordinal0 [0x00E2B215+1683989]
# 	Ordinal0 [0x00E36484+1729668]
# 	BaseThreadInitThunk [0x76D300F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77167BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77167B8E+238]

# %%
import pandas as pd

results_df = pd.DataFrame(results)
#result = results_df.transpose()
results_df.columns = ['date','content','tags','user_id','comment','like']
results_df
# Out:
#          date                                            content  \
# 0  2022-10-08  전 세계적으로 스마트폰 및 액세서리 커스텀 디자인으로 유명한 캐비아가 아이폰 14 ...
# 1  2022-10-08  "내 특기로 말하자면 관찰과 기록"이라 주창하는 잘 보고, 잘 기억하는 테크 넷을 ...
# 2  2022-10-07  지난달 디자이너 쳇 로의 컬렉션 쇼에서 패션 아이템으로 등장한 낫싱의 이어버즈, 이...
# 3  2022-10-07  테슬라의 CEO 일론 머스크의 트위터에 오랫동안 연기되었던 순수 전기 트럭 세미의 ...
# 4  2022-10-07  #광고 버버리 새 아우터웨어 캠페인 ‘나이트 크리처스(Night Creatures)...
#
#                                                 tags  \
# 0  [#caviar, #iphone, #iphone14, #case, #rolex, #...
# 1  [#leica, #suunto, #nikon, #sony, #z30, #tx660,...
# 2  [#nothing, #tech, #buds, #earbuds, #earphone, ...
# 3  [#tesla, #elonmusk, #pepsi, #semitruck, #allel...
# 4         [#광고, #버버리, #Burberry, #BurberryOuterwear]
#
#                                              user_id  \
# 0  [jaebeen_luv14, deirdre.thomas.35513, bvlckye,...
# 1                          [eguiajean, fstr.barbara]
# 2
# 3                [nut_head2022, o_o.6_6, itsmemrkim]
# 4                                                 []
#
#                                              comment    like
# 0  [😍😍😍갖고시프다~~😍❤️❤️❤️❤️❤️👏, That is over 63,000 U...   1,754
# 1                                  [Love it!💜💜💜💜, 道]   1,193
# 2                                                 []   1,366
# 3                 [Wow so Qte 😍🔥👏, 🔥🔥🔥, @juny0unger]   1,601
# 4                                                 []   1,163

# %%
results_df
# Out:
#             0                                                  1  \
# 0  2022-10-08  전 세계적으로 스마트폰 및 액세서리 커스텀 디자인으로 유명한 캐비아가 아이폰 14 ...
# 1  2022-10-08  "내 특기로 말하자면 관찰과 기록"이라 주창하는 잘 보고, 잘 기억하는 테크 넷을 ...
# 2  2022-10-07  지난달 디자이너 쳇 로의 컬렉션 쇼에서 패션 아이템으로 등장한 낫싱의 이어버즈, 이...
# 3  2022-10-07  테슬라의 CEO 일론 머스크의 트위터에 오랫동안 연기되었던 순수 전기 트럭 세미의 ...
# 4  2022-10-07  #광고 버버리 새 아우터웨어 캠페인 ‘나이트 크리처스(Night Creatures)...
#
#                                                    2  \
# 0  [#caviar, #iphone, #iphone14, #case, #rolex, #...
# 1  [#leica, #suunto, #nikon, #sony, #z30, #tx660,...
# 2  [#nothing, #tech, #buds, #earbuds, #earphone, ...
# 3  [#tesla, #elonmusk, #pepsi, #semitruck, #allel...
# 4         [#광고, #버버리, #Burberry, #BurberryOuterwear]
#
#                                                    3  \
# 0  [jaebeen_luv14, deirdre.thomas.35513, bvlckye,...
# 1                          [eguiajean, fstr.barbara]
# 2
# 3                [nut_head2022, o_o.6_6, itsmemrkim]
# 4                                                 []
#
#                                                    4       5
# 0  [😍😍😍갖고시프다~~😍❤️❤️❤️❤️❤️👏, That is over 63,000 U...   1,754
# 1                                  [Love it!💜💜💜💜, 道]   1,193
# 2                                                 []   1,366
# 3                 [Wow so Qte 😍🔥👏, 🔥🔥🔥, @juny0unger]   1,601
# 4                                                 []   1,163

# %%
results = results_df.transpose()

# %%
results.columns = ['date','content','tags','user_id','comment','like']
results
# Out:
#          date                                            content  \
# 0  2022-10-08  전 세계적으로 스마트폰 및 액세서리 커스텀 디자인으로 유명한 캐비아가 아이폰 14 ...
#
#                                                 tags  \
# 0  [#caviar, #iphone, #iphone14, #case, #rolex, #...
#
#                                              user_id  \
# 0  [jaebeen_luv14, deirdre.thomas.35513, bvlckye,...
#
#                                              comment    like
# 0  [😍😍😍갖고시프다~~😍❤️❤️❤️❤️❤️👏, That is over 63,000 U...   1,752
