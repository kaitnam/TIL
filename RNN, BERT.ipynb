# %%
# https://www.kaggle.com/code/tanulsingh077/deep-learning-for-nlp-zero-to-transformers-bert/notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU,SimpleRNN, Embedding
from keras.layers.core import Dense, Activation, Dropout
from tensorflow.keras.layers import BatchNormalization
from keras.utils import np_utils
from sklearn import preprocessing, decomposition, model_selection, metrics, pipeline
from keras.layers import GlobalMaxPooling1D, Conv1D, MaxPooling1D, Flatten, Bidirectional, SpatialDropout1D
from keras.preprocessing import sequence, text
from keras.callbacks import EarlyStopping


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff

# %%
# Detect hardware, return appropriate distribution strategy
try:
    # TPU detection. No parameters necessary if TPU_NAME environment variable is
    # set: this is always the case on Kaggle.
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy()

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# REPLICAS:  1

# %%
train = pd.read_csv("E:/Kaggle_Practice/Deep Learning For NLP_Zero To Transformers and BERT/jigsaw-toxic-comment-train.csv")
validation = pd.read_csv("E:/Kaggle_Practice/Deep Learning For NLP_Zero To Transformers and BERT/validation.csv")
test = pd.read_csv("E:/Kaggle_Practice/Deep Learning For NLP_Zero To Transformers and BERT/test.csv")

# %%
validation.comment_text.values
# Out:
# array(['Este usuario ni siquiera llega al rango de    hereje   . Por lo tanto debería ser quemado en la barbacoa para purificar su alma y nuestro aparato digestivo mediante su ingestión.    Skipe linkin 22px   Honor, valor, leltad.      17:48 13 mar 2008 (UTC)',
#        'Il testo di questa voce pare esser scopiazzato direttamente da qui. Immagino possano esserci problemi di copyright, nel fare cio .',
#        'Vale. Sólo expongo mi pasado. Todo tiempo pasado fue mejor, ni mucho menos, yo no quisiera retroceder 31 años a nivel particular. Las volveria a pasar putas.Fernando ',
#        ...,
#        'olum sız manyakmısınz siz adam sıze sanal yıldız vermıs bilmem nerenız kalkmıs bedava kole dıye calıstırıyorlar sızı siz hala uyuyuyn olmayan bi odul aldım dıye o odul birgun gercek olursa uzerine oturursun saygılarla',
#        'El mapa del reinado de Alhaken esta ligeramente exagerado en la zona del pirineo aragonés.Jaca por ejemplo fue tomada en el 780 (¡200 años antes de este reinado!)Tal vez vendría bien cambiar la imagen... 21:30 22 nov 2007 (CET)',
#        'lasciami la tua email per favore. ad ogni modo se leggi qui, l immagine proviene da uno stemma   della Seta-Gaetani-Bocca   in legno dell ottocento senza aquile ma con 2 leocorni. agoseta@yahoo.com'],
#       dtype=object)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223549 entries, 0 to 223548
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             223549 non-null  object
#  1   comment_text   223549 non-null  object
#  2   toxic          223549 non-null  int64
#  3   severe_toxic   223549 non-null  int64
#  4   obscene        223549 non-null  int64
#  5   threat         223549 non-null  int64
#  6   insult         223549 non-null  int64
#  7   identity_hate  223549 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 13.6+ MB

# %%
train.shape
# Out:
# (223549, 8)

# %%
train.drop(['severe_toxic','obscene','threat','insult','identity_hate'],axis=1,inplace=True)

# %%
train = train.loc[:12000,:] # loc[행,열] 즉 행이 지금 총 223548개 있는데 그중에 12000까지만 사용하고, 열은 다 사용한다.(:)
train.shape
# Out:
# (12001, 3)

# %%
train.head()
# Out:
#                  id                                       comment_text  toxic
# 0  0000997932d777bf  Explanation\nWhy the edits made under my usern...      0
# 1  000103f0d9cfb60f  D'aww! He matches this background colour I'm s...      0
# 2  000113f07ec002fd  Hey man, I'm really not trying to edit war. It...      0
# 3  0001b41b1c6bb37e  "\nMore\nI can't make any real suggestions on ...      0
# 4  0001d958c54c6e35  You, sir, are my hero. Any chance you remember...      0

# %%
# We will check the maximum number of words that can be present in a comment , this will help us in padding later

# %%
train['comment_text'].apply(lambda x:len(str(x).split())).max()
# Out:
# 1403

# %%
# Writing a function for getting auc score for validation

# %%
def roc_auc(predictions,target):
    '''
    This methods returns the AUC Score when given the Predictions
    and Labels
    '''
    
    fpr, tpr, thresholds = metrics.roc_curve(target, predictions)
    roc_auc = metrics.auc(fpr, tpr)
    return roc_auc

# %%
# Data Preparation

# %%
xtrain, xvalid, ytrain, yvalid = train_test_split(train.comment_text.values, train.toxic.values, 
                                                  stratify=train.toxic.values, 
                                                  random_state=42, 
                                                  test_size=0.2, shuffle=True)

# %%
# Simple RNN

# %%
# using keras tokenizer here
from tensorflow.keras.preprocessing.sequence import pad_sequences

token = text.Tokenizer(num_words=None)
max_len = 1500

token.fit_on_texts(list(xtrain) + list(xvalid))
xtrain_seq = token.texts_to_sequences(xtrain) #texts_to_sequences()을 이용하여 text 문장을 숫자로 이루어진 리스트로 만든다
xvalid_seq = token.texts_to_sequences(xvalid)

#zero pad the sequences
xtrain_pad = pad_sequences(xtrain_seq, maxlen=max_len) #길이를 max_len(1500)맞추고 빈자리는 0으로 채운다
xvalid_pad = pad_sequences(xvalid_seq, maxlen=max_len)

word_index = token.word_index # word_index 속성은 단어와 숫자의 키-값 쌍을 포함하는 딕셔너리를 반환. 반환할때 모든 알파벳은 소문자로 반환됨.

# %%
xtrain_seq
# Out:
# [[664,
#   65,
#   7,
#   19,
#   2262,
#   14102,
#   5,
#   2262,
#   20439,
#   6071,
#   4,
#   71,
#   32,
#   20440,
#   6620,
#   39,
#   6,
#   664,
#   65,
#   11,
#   8,
#   20441,
#   1502,
#   38,
#   6072],
#  [12,
#   1,
#   1008,
#   7,
#   23,
#   857,
#   35,
#   1503,
#   10,
#   1,
#   1676,
#   7,
#   23,
#   14,
#   1813,
#   25,
#   7301,
#   7,
#   23,
#   4420,
#   9,
#   7,
#   61,
#   900,
#   10,
#   1,
#   1676,
#   2,
#   64,
#   73,
#   11,
#   23,
#   48,
#   4,
#   7,
#   88,
#   37,
#   41,
#   61,
#   19,
#   55,
#   56,
#   245,
#   571,
#   1,
#   1676,
#   22,
#   41,
#   23,
#   53,
#   245,
#   35,
#   14103,
#   1,
#   1676,
#   23,
#   14,
#   5,
#   1442,
#   11,
#   23,
#   857,
#   7,
#   221,
#   7,
#   61,
#   19,
#   55,
#   119,
#   29,
#   427,
#   4,
#   78,
#   47,
#   19,
#   55,
#   1,
#   194,
#   303,
#   7,
#   1584,
#   9,
#   41,
#   23,
#   5,
#   2313,
#   12,
#   2928,
#   4,
#   13,
#   61,
#   2598,
#   17,
#   303,
#   12,
#   57,
#   315,
#   2,
#   16,
#   2114,
#   3,
#   533,
#   3813,
#   2,
#   1,
#   1676,
#   94,
#   84,
#   41,
#   8,
#   344,
#   5,
#   2464,
#   359,
#   12,
#   1503,
#   10,
#   1,
#   1676,
#   17,
#   7,
#   69,
#   11132,
#   2114,
#   4684,
#   4,
#   11133,
#   34,
#   1,
#   683,
#   572,
#   17,
#   11,
#   227,
#   91,
#   41,
#   8,
#   5,
#   120,
#   596,
#   22,
#   1,
#   427,
#   221,
#   6,
#   18,
#   20442,
#   21,
#   1676,
#   52,
#   39,
#   208,
#   6,
#   20,
#   1703,
#   3974,
#   3,
#   101,
#   548],
#  [11, 562, 48, 110, 1650, 4, 1959, 10, 1, 24, 359, 11, 38],
#  [51,
#   28,
#   1443,
#   15,
#   20443,
#   901,
#   41,
#   8,
#   5,
#   4685,
#   468,
#   9,
#   47,
#   2212,
#   660,
#   4,
#   901,
#   9,
#   11,
#   8,
#   1099,
#   50,
#   1312,
#   2,
#   296,
#   2,
#   1814,
#   10,
#   53,
#   313,
#   1413,
#   10,
#   62,
#   1052,
#   11,
#   8,
#   304,
#   555,
#   4,
#   225,
#   128,
#   51,
#   48,
#   5,
#   4686,
#   10,
#   5,
#   1198,
#   26,
#   249,
#   5656,
#   470,
#   93,
#   9,
#   128,
#   31,
#   198,
#   4686,
#   24,
#   4,
#   445,
#   20444,
#   10,
#   14104,
#   25,
#   1280,
#   31,
#   1,
#   215,
#   211,
#   304,
#   549,
#   379,
#   3,
#   2415,
#   5657,
#   20,
#   29,
#   15,
#   1432,
#   117,
#   9,
#   8,
#   225,
#   158,
#   369,
#   550,
#   26,
#   1130,
#   48,
#   5,
#   369,
#   117,
#   4,
#   5,
#   273,
#   117,
#   142,
#   459,
#   9,
#   1131,
#   387,
#   715,
#   4,
#   9,
#   1394,
#   20,
#   676,
#   57,
#   2599,
#   550,
#   4,
#   6621,
#   550,
#   9,
#   18,
#   3643,
#   32,
#   369,
#   550,
#   26,
#   17,
#   5,
#   433,
#   596,
#   44,
#   62,
#   48,
#   9365,
#   20445,
#   99,
#   11,
#   347,
#   31,
#   1988,
#   197,
#   5,
#   6073,
#   1,
#   234,
#   3,
#   435,
#   8,
#   9,
#   198,
#   85,
#   549,
#   1,
#   3814,
#   4,
#   1815,
#   3814,
#   715,
#   33,
#   14,
#   19,
#   330,
#   103,
#   2,
#   99,
#   11,
#   347,
#   40,
#   8,
#   124,
#   15,
#   22,
#   11,
#   8,
#   3516,
#   7302,
#   25,
#   164,
#   3,
#   1,
#   648,
#   527,
#   11134,
#   3,
#   369,
#   550,
#   129,
#   1,
#   432,
#   46,
#   8,
#   139,
#   14105,
#   17,
#   5,
#   4686,
#   549,
#   22,
#   11,
#   1313,
#   1,
#   653,
#   4686,
#   10,
#   1,
#   24,
#   616,
#   11,
#   61,
#   344,
#   16,
#   176,
#   763,
#   10,
#   53,
#   518,
#   1,
#   513,
#   54,
#   61,
#   16,
#   41,
#   25,
#   5,
#   9366,
#   46,
#   22,
#   661,
#   67,
#   691,
#   11,
#   47,
#   16,
#   5,
#   1414,
#   27,
#   104,
#   16,
#   9367,
#   22,
#   1,
#   508,
#   117,
#   82,
#   5658,
#   10,
#   62,
#   1247,
#   4,
#   84,
#   9,
#   8,
#   205,
#   5,
#   199,
#   15,
#   1,
#   24,
#   27,
#   8,
#   802,
#   26,
#   10,
#   308,
#   41,
#   8,
#   5,
#   1562,
#   2536,
#   9,
#   925,
#   719,
#   96,
#   62,
#   910,
#   35,
#   44,
#   360,
#   73,
#   11,
#   8,
#   205,
#   5,
#   2744,
#   234,
#   8,
#   79,
#   20,
#   508,
#   550,
#   369,
#   10,
#   1,
#   24,
#   117,
#   322,
#   20446,
#   176,
#   51,
#   1,
#   115,
#   369,
#   117,
#   10,
#   42,
#   1247,
#   4,
#   41,
#   18,
#   1395,
#   3,
#   95,
#   94,
#   1741,
#   18,
#   153,
#   11135,
#   11136,
#   20447,
#   176,
#   62,
#   4953,
#   54,
#   203,
#   94,
#   764,
#   10,
#   1,
#   819,
#   161,
#   117],
#  [13, 8198, 274, 3, 552, 692, 43, 92, 4954, 335, 17, 20448, 4, 20449],
#  [7303,
#   3975,
#   5,
#   27,
#   186,
#   355,
#   145,
#   5,
#   968,
#   9,
#   344,
#   1884,
#   9,
#   41,
#   23,
#   44,
#   355,
#   402,
#   205,
#   7303,
#   25,
#   7304,
#   8,
#   9368,
#   6,
#   1433,
#   9,
#   422,
#   44,
#   355,
#   322,
#   6,
#   3037,
#   11,
#   84,
#   41,
#   8,
#   44,
#   355,
#   1,
#   4178,
#   8,
#   2,
#   263],
#  [180,
#   199,
#   7,
#   463,
#   68,
#   26,
#   7,
#   19,
#   5,
#   180,
#   14106,
#   4,
#   77,
#   1926,
#   10,
#   7305,
#   4,
#   43,
#   5,
#   5283,
#   15,
#   11,
#   264,
#   68,
#   40,
#   11,
#   8,
#   252,
#   4955,
#   11,
#   4,
#   1214,
#   11,
#   729,
#   634],
#  [137,
#   1814,
#   29,
#   14107,
#   853,
#   8199,
#   7,
#   23,
#   454,
#   12,
#   103,
#   15,
#   853,
#   8199,
#   4,
#   621,
#   1087,
#   5,
#   2027,
#   131,
#   10,
#   1,
#   226,
#   35,
#   60,
#   1066,
#   244,
#   41,
#   8,
#   5,
#   627,
#   9,
#   1816,
#   15,
#   1053,
#   1054,
#   20450,
#   216,
#   15,
#   5,
#   4179,
#   4,
#   11137,
#   1885,
#   665,
#   1,
#   9369,
#   1927,
#   5,
#   14108,
#   3,
#   1,
#   20451,
#   1927,
#   50,
#   23,
#   5659,
#   31,
#   14109,
#   5660,
#   4,
#   1281,
#   171,
#   2,
#   699,
#   26,
#   14,
#   154,
#   522,
#   60,
#   2213,
#   2314,
#   2,
#   14110,
#   573,
#   10,
#   60,
#   20452,
#   230,
#   1282,
#   14111,
#   23,
#   1215,
#   216,
#   5,
#   5661,
#   3,
#   1,
#   14109,
#   50,
#   4,
#   60,
#   1817,
#   5661,
#   14112,
#   14113,
#   82,
#   119,
#   2,
#   900,
#   5,
#   20453,
#   3,
#   5660,
#   7306,
#   20,
#   5662,
#   1,
#   234,
#   8,
#   9,
#   41,
#   8,
#   44,
#   398,
#   3,
#   65,
#   1282,
#   14111,
#   8,
#   81,
#   9,
#   50,
#   23,
#   1215,
#   7,
#   64,
#   9,
#   29,
#   72,
#   6,
#   119,
#   489,
#   2353,
#   601,
#   1164,
#   20454,
#   190,
#   62,
#   2028,
#   15,
#   157,
#   389,
#   3976,
#   14112,
#   14113,
#   17,
#   1,
#   1817,
#   5661,
#   17,
#   6,
#   19,
#   194,
#   530,
#   15,
#   1,
#   275,
#   39,
#   6,
#   49,
#   209,
#   171,
#   62,
#   493,
#   3976,
#   157,
#   25,
#   1071,
#   277,
#   1,
#   2115,
#   493,
#   89],
#  [78, 279, 67, 187, 1818, 20455, 1531, 3368, 4956, 380],
#  [6, 18, 5, 20456, 450],
#  [13,
#   8,
#   34,
#   309,
#   1,
#   6074,
#   83,
#   159,
#   43,
#   233,
#   2,
#   21,
#   38,
#   27,
#   2,
#   201,
#   6,
#   2,
#   16,
#   56,
#   1625,
#   20,
#   3247,
#   1989,
#   473,
#   15,
#   22,
#   6,
#   48,
#   26,
#   49,
#   296,
#   2,
#   16,
#   56,
#   741,
#   20,
#   21,
#   1989,
#   22,
#   1585,
#   1156,
#   192,
#   19,
#   1346,
#   76,
#   1,
#   138,
#   234,
#   11,
#   87,
#   16,
#   83,
#   2,
#   20457,
#   1,
#   2313,
#   9,
#   41,
#   8,
#   225,
#   5,
#   234],
#  [20458,
#   96,
#   5,
#   244,
#   1819,
#   48,
#   13,
#   8,
#   5,
#   383,
#   7307,
#   370,
#   11,
#   8,
#   900,
#   31,
#   11138,
#   48,
#   6,
#   14,
#   1742,
#   21,
#   5,
#   6075,
#   6,
#   1820,
#   12,
#   21,
#   2263,
#   4,
#   179,
#   612,
#   10,
#   4687],
#  [471,
#   20459,
#   6,
#   113,
#   1990,
#   296,
#   86,
#   5,
#   356,
#   1991,
#   35,
#   146,
#   4,
#   6,
#   193,
#   255,
#   9,
#   11,
#   8,
#   14,
#   5,
#   202,
#   451,
#   40,
#   7,
#   69,
#   294,
#   8,
#   911,
#   2,
#   1,
#   57,
#   3977,
#   192,
#   21,
#   2416,
#   10,
#   259,
#   132,
#   35,
#   20460,
#   7308,
#   22,
#   7,
#   23,
#   2,
#   170,
#   164,
#   48,
#   40,
#   5,
#   1464,
#   250,
#   450,
#   78,
#   9,
#   104,
#   16,
#   5284,
#   17,
#   5,
#   202,
#   451,
#   26,
#   7,
#   182,
#   155,
#   9],
#  [333,
#   21,
#   294,
#   5,
#   6076,
#   74,
#   805,
#   34,
#   1775,
#   2,
#   4957,
#   2315,
#   8200,
#   17,
#   5,
#   1704,
#   3815,
#   7,
#   747,
#   20,
#   21,
#   408,
#   5285],
#  [20461,
#   602,
#   1482,
#   11139,
#   1088,
#   14114,
#   677,
#   20462,
#   787,
#   14115,
#   352,
#   1132,
#   1705,
#   20463,
#   20464,
#   20465,
#   20466,
#   831,
#   5663,
#   247,
#   11140,
#   1370,
#   5664,
#   5664,
#   5664,
#   4688,
#   15,
#   1,
#   9370,
#   11141,
#   9371,
#   11142,
#   20467,
#   291,
#   4,
#   1296,
#   20468,
#   2465,
#   11143,
#   542,
#   2827,
#   20469,
#   901,
#   5663,
#   247,
#   20470,
#   20471,
#   5664,
#   5664,
#   5664,
#   4688,
#   15,
#   1,
#   9370,
#   11141,
#   9371,
#   11142,
#   20472,
#   20473,
#   2164,
#   20474,
#   14116,
#   3,
#   5286,
#   20475,
#   20476,
#   5663,
#   247,
#   11144,
#   20477,
#   5664,
#   5664,
#   5664,
#   4688,
#   15,
#   1,
#   9370,
#   11141,
#   9371,
#   11142,
#   20478,
#   20479,
#   20480,
#   20481,
#   5,
#   20482,
#   5,
#   20483,
#   376,
#   20484,
#   8201,
#   11145,
#   11146],
#  [1037,
#   4958,
#   2745,
#   8,
#   11,
#   409,
#   2,
#   118,
#   9,
#   1992,
#   22,
#   5,
#   2071,
#   1504,
#   1651,
#   31,
#   7309,
#   11147,
#   1,
#   4959,
#   5287,
#   78,
#   5,
#   894,
#   1504,
#   2071,
#   700,
#   45,
#   2165,
#   1,
#   138,
#   5287,
#   17,
#   5,
#   2316,
#   1504,
#   2071,
#   700,
#   1651,
#   22,
#   37,
#   104,
#   1,
#   1960,
#   93,
#   2071,
#   1651,
#   16,
#   418,
#   1037,
#   2214,
#   4,
#   1,
#   1415,
#   93,
#   2071,
#   1651,
#   418,
#   4958,
#   2214,
#   22,
#   37,
#   7,
#   70,
#   13,
#   8,
#   5,
#   313,
#   645,
#   25,
#   46,
#   116,
#   3,
#   5665,
#   217],
#  [7,
#   69,
#   14,
#   10,
#   5,
#   11148,
#   20,
#   1821,
#   4,
#   7,
#   33,
#   14,
#   219,
#   9,
#   7,
#   19,
#   53,
#   523,
#   4960,
#   22,
#   29,
#   427,
#   20485,
#   2537,
#   31,
#   260,
#   9,
#   427,
#   61,
#   16,
#   181,
#   12,
#   2537,
#   769,
#   75,
#   33,
#   6,
#   219,
#   9,
#   44,
#   933,
#   61,
#   16,
#   499,
#   232,
#   678,
#   202,
#   514,
#   114,
#   17,
#   1,
#   46,
#   9,
#   6622,
#   28,
#   208],
#  [981,
#   1264,
#   142,
#   5288,
#   190,
#   1,
#   436,
#   940,
#   6,
#   185,
#   2,
#   8202,
#   1072,
#   946,
#   1371,
#   24,
#   12,
#   189,
#   649,
#   180,
#   52,
#   18,
#   1216,
#   42,
#   177,
#   358,
#   2,
#   16,
#   625,
#   4,
#   189,
#   41,
#   8,
#   5,
#   149,
#   34,
#   1,
#   477,
#   38,
#   27,
#   2,
#   277,
#   125,
#   436,
#   940,
#   17,
#   52,
#   18,
#   4421,
#   177,
#   4,
#   806,
#   232,
#   112,
#   4422,
#   22,
#   6,
#   19,
#   53,
#   4180,
#   49,
#   2929,
#   95,
#   17,
#   5,
#   120,
#   149,
#   34,
#   38,
#   8202,
#   1072,
#   946,
#   1371,
#   25,
#   1327,
#   1,
#   477,
#   38,
#   27,
#   140,
#   6,
#   20486],
#  [302,
#   7,
#   19,
#   147,
#   95,
#   220,
#   4,
#   7,
#   45,
#   91,
#   201,
#   6,
#   2,
#   494,
#   171,
#   74,
#   12,
#   21,
#   706,
#   14,
#   9,
#   11,
#   1347,
#   10,
#   1,
#   309,
#   1,
#   46,
#   1108,
#   8,
#   17,
#   377,
#   17,
#   1,
#   57,
#   26,
#   6,
#   194,
#   19,
#   62,
#   958,
#   12,
#   21,
#   485,
#   20487],
#  [566,
#   408,
#   180,
#   11149,
#   4423,
#   288,
#   9,
#   1,
#   583,
#   345,
#   11150,
#   34,
#   959,
#   941,
#   16,
#   792,
#   297,
#   3,
#   2072,
#   26,
#   109,
#   14,
#   764,
#   2,
#   431,
#   8203,
#   770,
#   173,
#   2,
#   20488,
#   20489,
#   206,
#   336,
#   707,
#   3816,
#   3644,
#   20490,
#   926,
#   20491,
#   11149,
#   11151,
#   1626,
#   20492,
#   926,
#   61,
#   1,
#   273,
#   627,
#   3,
#   1,
#   24,
#   16,
#   479,
#   25,
#   8,
#   41,
#   5,
#   2746,
#   9,
#   2600,
#   1009,
#   2,
#   13,
#   274],
#  [65, 1, 982, 18, 6, 4, 129, 88, 6, 96, 13, 2466, 617, 363, 3517, 934],
#  [7,
#   261,
#   252,
#   277,
#   11,
#   4,
#   279,
#   5,
#   199,
#   2,
#   1,
#   240,
#   1706,
#   9,
#   1,
#   103,
#   16,
#   185,
#   2,
#   1,
#   3145,
#   14117,
#   2317,
#   24,
#   9,
#   6,
#   1144,
#   25,
#   107,
#   136,
#   9372],
#  [3978,
#   2930,
#   12,
#   198,
#   2029,
#   613,
#   7,
#   185,
#   13,
#   519,
#   2,
#   1,
#   2601,
#   1,
#   158,
#   420,
#   1886,
#   3,
#   8204,
#   18,
#   1,
#   2116,
#   622,
#   4,
#   1,
#   1483,
#   2,
#   1887,
#   622,
#   54,
#   20493,
#   190,
#   20,
#   1,
#   645,
#   9,
#   13,
#   693,
#   203,
#   1505,
#   1,
#   708,
#   128,
#   10,
#   28,
#   519,
#   422,
#   5,
#   3978,
#   645,
#   12,
#   1,
#   3369,
#   440,
#   2029,
#   613,
#   298,
#   9,
#   25,
#   1073,
#   42,
#   2030,
#   22,
#   187,
#   364,
#   9,
#   13,
#   693,
#   203,
#   34,
#   42,
#   557,
#   1,
#   3978,
#   1199,
#   12,
#   198,
#   2029,
#   613,
#   78,
#   344,
#   211,
#   5,
#   234,
#   6,
#   59,
#   3817,
#   9,
#   234,
#   31,
#   581,
#   1,
#   46,
#   519,
#   9,
#   109,
#   398,
#   1,
#   2930,
#   12,
#   198,
#   2029,
#   613,
#   6,
#   3817,
#   11,
#   31,
#   888,
#   1,
#   131,
#   9,
#   109,
#   494,
#   1,
#   2930,
#   10,
#   534,
#   2,
#   33,
#   9,
#   6,
#   115,
#   19,
#   2,
#   367,
#   42,
#   1,
#   283,
#   9,
#   7,
#   185,
#   2,
#   1,
#   2116,
#   2602,
#   693,
#   22,
#   187,
#   14,
#   1328,
#   2,
#   99,
#   9,
#   1312,
#   78,
#   49,
#   59,
#   72,
#   13,
#   693,
#   316,
#   253,
#   147,
#   305,
#   42,
#   153,
#   265,
#   110,
#   4,
#   136,
#   136,
#   136,
#   56,
#   1200,
#   28,
#   167,
#   13,
#   1100,
#   1,
#   2264,
#   622,
#   3,
#   535,
#   11152,
#   31,
#   1563,
#   20494,
#   43,
#   55,
#   696,
#   169,
#   363,
#   820,
#   365,
#   11,
#   1776,
#   1,
#   4685,
#   3978,
#   2930,
#   12,
#   198,
#   2029,
#   613,
#   20495,
#   697,
#   23,
#   9,
#   1,
#   2116,
#   2602,
#   102,
#   5,
#   106,
#   1348,
#   2215,
#   67,
#   3,
#   1,
#   3645,
#   3370,
#   234,
#   5,
#   234,
#   54,
#   2029,
#   1627,
#   2747,
#   8205,
#   211,
#   11,
#   211,
#   198,
#   2029,
#   613,
#   10,
#   5,
#   20496,
#   211,
#   1,
#   1297,
#   466,
#   9,
#   983,
#   61,
#   14,
#   19,
#   2,
#   11153,
#   305,
#   3248,
#   3,
#   994,
#   779,
#   2,
#   144],
#  [889, 3, 29, 671, 362, 1822, 14, 268],
#  [143,
#   3,
#   4181,
#   7310,
#   1109,
#   8206,
#   28,
#   238,
#   449,
#   21,
#   143,
#   3,
#   13,
#   314,
#   18,
#   14,
#   7311,
#   52,
#   18,
#   2603,
#   7,
#   19,
#   81,
#   337,
#   191,
#   403,
#   1823,
#   1928,
#   20497,
#   4,
#   69,
#   1,
#   115,
#   2,
#   2604,
#   9,
#   7,
#   19,
#   14,
#   119,
#   487,
#   1265,
#   821,
#   2,
#   1,
#   7312,
#   3,
#   1,
#   314,
#   145,
#   62,
#   894,
#   256,
#   3,
#   3818,
#   28,
#   2931,
#   28,
#   1024,
#   3819,
#   23,
#   2,
#   1586,
#   1,
#   103,
#   11154,
#   15,
#   153,
#   286,
#   1564,
#   65,
#   19,
#   55,
#   1484,
#   960,
#   10,
#   174,
#   28,
#   2603,
#   858,
#   32,
#   1,
#   156,
#   9,
#   1,
#   143,
#   23,
#   14,
#   9373,
#   6,
#   419,
#   2,
#   19,
#   51,
#   11155,
#   1,
#   24,
#   4,
#   558,
#   126,
#   1,
#   20498,
#   23,
#   9,
#   389,
#   3,
#   1532,
#   1,
#   103,
#   15,
#   1,
#   27,
#   145,
#   42,
#   11,
#   43,
#   55,
#   41,
#   12,
#   62,
#   83,
#   40,
#   8,
#   1,
#   3979,
#   2,
#   237,
#   11,
#   4,
#   865,
#   12,
#   2028,
#   654,
#   2031,
#   51,
#   4961,
#   22,
#   7,
#   255,
#   11,
#   1372,
#   11,
#   227,
#   9,
#   30,
#   9374,
#   2,
#   585,
#   17,
#   5,
#   123,
#   32,
#   1,
#   11156,
#   3,
#   339,
#   2417,
#   780,
#   67,
#   5,
#   1824,
#   2,
#   8207,
#   25,
#   11157,
#   5,
#   1707,
#   123,
#   43,
#   459,
#   11,
#   4,
#   299,
#   28,
#   57,
#   585,
#   32,
#   1,
#   5666,
#   3,
#   339,
#   2417,
#   20,
#   123,
#   248,
#   67,
#   7,
#   19,
#   459,
#   11,
#   832,
#   10,
#   5,
#   1777,
#   317,
#   3,
#   1,
#   11156,
#   3820,
#   17,
#   7,
#   462,
#   2,
#   6,
#   10,
#   28,
#   666,
#   11,
#   23,
#   678,
#   9,
#   1,
#   2166,
#   3,
#   220,
#   1,
#   388,
#   8207,
#   4,
#   1,
#   11157,
#   88,
#   14,
#   225,
#   68,
#   1,
#   3146,
#   3,
#   8208,
#   7310,
#   52,
#   220,
#   8209,
#   3371,
#   28,
#   464,
#   395,
#   102,
#   295,
#   20499,
#   2,
#   1,
#   543,
#   20,
#   28,
#   1416,
#   779,
#   369,
#   31,
#   8208,
#   7310,
#   2,
#   1,
#   8210,
#   5667,
#   84,
#   50,
#   3980,
#   10,
#   1606,
#   20,
#   60,
#   2418,
#   20500,
#   6,
#   1708,
#   20,
#   1,
#   508,
#   248,
#   780,
#   14118,
#   737,
#   1314,
#   3,
#   1606,
#   11158,
#   1329,
#   2117,
#   2071,
#   6077,
#   2265,
#   2316,
#   7313,
#   3,
#   2354,
#   2,
#   11159,
#   4181,
#   7310,
#   3,
#   20501,
#   10,
#   20502,
#   4,
#   60,
#   11160,
#   50,
#   3980,
#   20,
#   60,
#   2418,
#   10,
#   414,
#   20503,
#   1053,
#   894,
#   14119,
#   14118,
#   737,
#   1314,
#   3,
#   1606,
#   11158,
#   1329,
#   2117,
#   2071,
#   490,
#   3518,
#   7313,
#   3,
#   2354,
#   4,
#   20504,
#   2,
#   14120,
#   1888,
#   853,
#   7310,
#   739,
#   2213,
#   3,
#   4,
#   14120,
#   2,
#   11159,
#   4181,
#   7310,
#   87,
#   662,
#   14119,
#   7,
#   3147,
#   22,
#   7,
#   19,
#   55,
#   165,
#   3646,
#   10,
#   28,
#   238,
#   2,
#   6,
#   26,
#   6,
#   266,
#   255,
#   9,
#   11,
#   23,
#   1004,
#   625,
#   103,
#   54,
#   34,
#   1,
#   83,
#   23,
#   14,
#   15,
#   1,
#   686,
#   9,
#   7,
#   23,
#   3647,
#   2,
#   1586,
#   20,
#   30,
#   983,
#   14,
#   352,
#   458,
#   4,
#   2605,
#   7,
#   231,
#   6,
#   19,
#   14,
#   2216,
#   20,
#   21,
#   143,
#   22,
#   6,
#   1709,
#   53,
#   354,
#   7314,
#   49,
#   793,
#   36,
#   3249,
#   4962,
#   3648,
#   2932],
#  [134, 137, 201, 36],
#  [13, 8, 21, 273, 522, 175, 86, 29, 1778],
#  [306,
#   108,
#   3,
#   6623,
#   737,
#   917,
#   1710,
#   5,
#   284,
#   43,
#   55,
#   618,
#   15,
#   6623,
#   737,
#   917,
#   1710,
#   1118,
#   9,
#   11,
#   16,
#   1349,
#   166,
#   32,
#   30,
#   515,
#   3247,
#   11161,
#   176,
#   1,
#   412,
#   12,
#   306,
#   108,
#   85,
#   9,
#   33,
#   14,
#   1145,
#   1004,
#   30,
#   412,
#   87,
#   16,
#   166,
#   34,
#   53,
#   83,
#   49,
#   64,
#   1,
#   438,
#   12,
#   40,
#   8,
#   748,
#   902,
#   17,
#   29,
#   555,
#   24,
#   4,
#   22,
#   6,
#   39,
#   1074,
#   75,
#   1,
#   275,
#   3,
#   13,
#   24,
#   8,
#   555,
#   6,
#   87,
#   946,
#   1,
#   1989,
#   2,
#   33,
#   13,
#   170,
#   15,
#   1,
#   357,
#   3,
#   1,
#   24,
#   4,
#   279,
#   5,
#   199,
#   15,
#   1,
#   819,
#   38,
#   27,
#   911,
#   21,
#   559,
#   49,
#   33,
#   14,
#   277,
#   1,
#   306,
#   108,
#   284,
#   146,
#   26,
#   59,
#   1743,
#   2,
#   170,
#   103,
#   2,
#   1,
#   24,
#   9,
#   47,
#   1565,
#   107,
#   2032,
#   544,
#   176,
#   1,
#   438,
#   22,
#   6,
#   70,
#   9,
#   13,
#   423,
#   23,
#   618,
#   63,
#   10,
#   1133,
#   6,
#   87,
#   946,
#   1,
#   108,
#   2,
#   33,
#   13,
#   170,
#   15,
#   1,
#   357,
#   3,
#   1,
#   27,
#   51,
#   650,
#   1,
#   1010,
#   306,
#   108,
#   25,
#   1711,
#   284,
#   4,
#   279,
#   5,
#   199,
#   15,
#   1,
#   3148,
#   38,
#   27,
#   911,
#   21,
#   559,
#   49,
#   33,
#   14,
#   277,
#   1,
#   306,
#   108,
#   284,
#   146,
#   38,
#   2,
#   36],
#  [91,
#   142,
#   1506,
#   1,
#   720,
#   437,
#   165,
#   6624,
#   1164,
#   8,
#   388,
#   352,
#   17,
#   105,
#   1,
#   1485,
#   437,
#   3,
#   7315,
#   20505,
#   720,
#   8,
#   14,
#   10,
#   60,
#   161,
#   7316,
#   54,
#   7,
#   69,
#   5668,
#   26,
#   10,
#   9,
#   3,
#   60,
#   8211,
#   20506,
#   4689,
#   10,
#   1,
#   14121,
#   7,
#   14122,
#   1,
#   883,
#   1201,
#   10,
#   1,
#   2606,
#   15,
#   20507,
#   9375,
#   399,
#   3,
#   4690,
#   7,
#   287,
#   14123,
#   3,
#   1,
#   20508,
#   1066,
#   10,
#   1,
#   1296,
#   3,
#   6625,
#   1,
#   9376,
#   14124,
#   7315,
#   20509,
#   20510,
#   2,
#   1,
#   4963,
#   4,
#   1038,
#   74,
#   1,
#   6078,
#   20511,
#   20512,
#   20513,
#   14121,
#   7,
#   14122,
#   9377,
#   20514,
#   20515,
#   1315,
#   2266,
#   11162,
#   3649,
#   490,
#   1650,
#   9376,
#   14124,
#   14123,
#   2467,
#   1350,
#   1825,
#   1217,
#   11163,
#   1712,
#   120,
#   352,
#   4,
#   6624,
#   1164,
#   11163,
#   1712,
#   388,
#   352,
#   437,
#   6079,
#   39,
#   16,
#   205,
#   1039,
#   20,
#   1,
#   9378,
#   5666,
#   20516,
#   3821],
#  [49,
#   33,
#   14,
#   749,
#   122,
#   17,
#   6,
#   88,
#   20,
#   13,
#   72,
#   2,
#   20517,
#   1396,
#   22,
#   6,
#   353,
#   2,
#   33,
#   37,
#   6,
#   45,
#   16,
#   181,
#   32,
#   143,
#   118,
#   14125,
#   14126],
#  [13,
#   8,
#   40,
#   7,
#   292,
#   17,
#   110,
#   5289,
#   890,
#   20518,
#   4,
#   969,
#   20519,
#   1040,
#   6626,
#   5290,
#   14127,
#   6080,
#   4424,
#   14128,
#   5290,
#   7,
#   20520,
#   20521,
#   6627,
#   9379,
#   20522,
#   20523,
#   20524,
#   7317,
#   20525,
#   14114,
#   679,
#   189,
#   1566,
#   942,
#   679,
#   189,
#   3250,
#   9380,
#   20526,
#   20527,
#   20528,
#   14129,
#   4691,
#   6626,
#   5290,
#   14127,
#   6080,
#   4424,
#   14128,
#   848,
#   20529,
#   763,
#   3372,
#   1174,
#   1,
#   317,
#   8,
#   14,
#   891,
#   2,
#   129,
#   7,
#   612,
#   20530,
#   484],
#  [1019,
#   3,
#   3149,
#   4,
#   1,
#   3149,
#   5291,
#   7,
#   70,
#   3149,
#   61,
#   16,
#   185,
#   67,
#   84,
#   11,
#   23,
#   5,
#   531,
#   11,
#   66,
#   102,
#   5,
#   5291],
#  [89, 126, 12, 42, 21, 1444],
#  [333,
#   20531,
#   7318,
#   4,
#   224,
#   2,
#   30,
#   140,
#   6,
#   12,
#   21,
#   348,
#   7,
#   423,
#   9,
#   46,
#   3,
#   1,
#   115,
#   85,
#   6,
#   646,
#   537,
#   2,
#   16,
#   1744,
#   20,
#   5,
#   496,
#   20,
#   54,
#   6,
#   87,
#   19,
#   5,
#   586,
#   3,
#   452,
#   10,
#   57,
#   415,
#   6,
#   87,
#   144,
#   11,
#   1157,
#   2,
#   280,
#   35,
#   9,
#   496,
#   10,
#   5,
#   574,
#   4,
#   1991,
#   116,
#   67,
#   6,
#   18,
#   160,
#   12,
#   25,
#   1850,
#   1,
#   275,
#   3,
#   9,
#   24,
#   21,
#   460,
#   348,
#   87,
#   19,
#   253,
#   55,
#   326,
#   12,
#   13,
#   106,
#   207,
#   2,
#   3822,
#   1,
#   4692,
#   3,
#   108,
#   6,
#   193,
#   48,
#   2,
#   2607,
#   21,
#   24,
#   154,
#   2167,
#   78,
#   201,
#   36,
#   25,
#   53,
#   57,
#   240,
#   2,
#   8212,
#   11,
#   2,
#   482,
#   888,
#   5,
#   2607,
#   24,
#   51,
#   1507,
#   21,
#   90,
#   117,
#   34,
#   1,
#   357,
#   3,
#   1,
#   2468,
#   84,
#   6,
#   18,
#   1417,
#   10,
#   4,
#   72,
#   9,
#   27,
#   17,
#   6,
#   47,
#   53,
#   57,
#   22,
#   1,
#   27,
#   6,
#   332,
#   43,
#   253,
#   55,
#   166,
#   32,
#   30,
#   26,
#   6,
#   113,
#   2,
#   1826,
#   1,
#   177,
#   32,
#   11,
#   2,
#   80,
#   12,
#   9,
#   2607,
#   59,
#   1743,
#   2,
#   201,
#   264,
#   32,
#   13,
#   184,
#   4,
#   52,
#   45,
#   903,
#   11,
#   2,
#   21,
#   90,
#   27,
#   1,
#   46,
#   3150,
#   596,
#   58,
#   33,
#   19,
#   10,
#   1567,
#   20,
#   3151,
#   3,
#   452,
#   8,
#   9,
#   1202,
#   128,
#   31,
#   56,
#   93,
#   46,
#   215,
#   45,
#   1174,
#   16,
#   181,
#   32,
#   143,
#   11,
#   8,
#   66,
#   1099,
#   4182,
#   9,
#   30,
#   748,
#   109,
#   14,
#   970,
#   192,
#   2,
#   19,
#   4425,
#   54,
#   892,
#   173,
#   95,
#   2,
#   46,
#   672,
#   25,
#   3251,
#   22,
#   21,
#   603,
#   109,
#   19,
#   114,
#   5,
#   117,
#   11,
#   47,
#   16,
#   11164,
#   12,
#   6,
#   2,
#   324,
#   5,
#   237,
#   3,
#   603,
#   22,
#   6,
#   18,
#   2748,
#   4,
#   454,
#   12,
#   137,
#   49,
#   233,
#   2,
#   1,
#   120,
#   3981,
#   137,
#   27,
#   129,
#   1961,
#   1373,
#   39,
#   468,
#   53,
#   4180,
#   6,
#   19,
#   6,
#   39,
#   66,
#   51,
#   721,
#   15,
#   21,
#   90,
#   27,
#   4,
#   159,
#   45,
#   318,
#   74,
#   1827,
#   2,
#   468,
#   21,
#   245,
#   63,
#   18,
#   5,
#   286,
#   57,
#   101,
#   251,
#   12,
#   3152,
#   1,
#   752,
#   1110,
#   3,
#   30,
#   73,
#   2,
#   72,
#   5,
#   27,
#   137,
#   122,
#   1175,
#   73,
#   2,
#   280,
#   5,
#   313,
#   24,
#   904,
#   3,
#   352,
#   7,
#   231,
#   6,
#   854,
#   143,
#   63,
#   4,
#   86,
#   5,
#   895,
#   49,
#   576,
#   21,
#   117,
#   15,
#   38,
#   122,
#   197,
#   516,
#   971,
#   13,
#   45,
#   815,
#   1119,
#   21,
#   117,
#   4,
#   1,
#   437,
#   22,
#   6,
#   19,
#   53,
#   245,
#   340,
#   76,
#   30,
#   129,
#   2,
#   201,
#   5,
#   212,
#   25,
#   201,
#   36,
#   15,
#   28,
#   38,
#   27,
#   126,
#   224],
#  [18,
#   6,
#   5,
#   5669,
#   11165,
#   33,
#   6,
#   1374,
#   2469,
#   2318,
#   1055,
#   188,
#   185,
#   31,
#   2828,
#   1677,
#   4426,
#   3823],
#  [6,
#   39,
#   70,
#   40,
#   6,
#   48,
#   35,
#   157,
#   94,
#   22,
#   40,
#   187,
#   364,
#   8,
#   151,
#   4,
#   7,
#   59,
#   261,
#   20,
#   11,
#   6,
#   168,
#   239,
#   2217,
#   21,
#   416,
#   6,
#   59,
#   100,
#   2,
#   5670,
#   6628,
#   27,
#   4,
#   64,
#   5670,
#   1779,
#   23,
#   5,
#   377,
#   450,
#   187,
#   66,
#   14,
#   905,
#   2,
#   16,
#   1351,
#   11166,
#   63,
#   34,
#   42,
#   972,
#   12,
#   73,
#   11,
#   3519,
#   2,
#   1,
#   24,
#   116,
#   2,
#   2218,
#   503,
#   597],
#  [22,
#   50,
#   1828,
#   20532,
#   7319,
#   78,
#   11,
#   8,
#   361,
#   213,
#   9,
#   61,
#   19,
#   107,
#   310,
#   10,
#   1,
#   24],
#  [37,
#   394,
#   1,
#   519,
#   104,
#   16,
#   164,
#   48,
#   145,
#   7320,
#   20533,
#   10,
#   1508,
#   20534,
#   2073,
#   2,
#   1850,
#   3252,
#   32,
#   1,
#   969,
#   151,
#   26,
#   66,
#   1745,
#   3982,
#   74,
#   3373,
#   3252,
#   4,
#   7321,
#   4,
#   51,
#   279,
#   11,
#   34,
#   9,
#   1,
#   3983,
#   251,
#   2,
#   1,
#   672,
#   78,
#   61,
#   16,
#   330,
#   199,
#   7,
#   582,
#   1,
#   519,
#   2,
#   446,
#   1929,
#   81,
#   37,
#   1,
#   303,
#   87,
#   14,
#   16,
#   741,
#   38],
#  [7, 51, 284, 11, 37, 62, 794, 39, 299, 11, 38],
#  [368,
#   48,
#   2,
#   296,
#   2,
#   137,
#   104,
#   6,
#   461,
#   21,
#   2355,
#   15,
#   75,
#   6,
#   82,
#   181,
#   4,
#   39,
#   6,
#   70,
#   3,
#   210,
#   6,
#   104,
#   33,
#   2,
#   7322,
#   1,
#   1089,
#   9,
#   1352,
#   2,
#   1,
#   208],
#  [22,
#   5,
#   9381,
#   9382,
#   5,
#   7323,
#   10,
#   1,
#   20535,
#   8,
#   9,
#   40,
#   6,
#   424,
#   5,
#   20536,
#   7,
#   81,
#   201,
#   67,
#   6,
#   1025,
#   105,
#   1961],
#  [788, 3374, 4, 4693],
#  [362,
#   1822,
#   837,
#   7,
#   324,
#   1,
#   859,
#   6629,
#   1158,
#   1822,
#   16,
#   3253,
#   7,
#   23,
#   259,
#   153,
#   720,
#   4427,
#   2,
#   14130,
#   20537,
#   789,
#   488,
#   7,
#   1120,
#   221,
#   17,
#   22,
#   7,
#   104,
#   16,
#   1993,
#   5,
#   101,
#   1824,
#   49,
#   837,
#   28,
#   1822,
#   37,
#   7,
#   39,
#   482,
#   31,
#   581,
#   5671,
#   32,
#   184,
#   3,
#   4183],
#  [87,
#   58,
#   144,
#   76,
#   65,
#   8,
#   294,
#   1,
#   24,
#   2219,
#   604,
#   1,
#   24,
#   2074,
#   371,
#   1,
#   543,
#   35,
#   1,
#   11167,
#   277,
#   1,
#   1780,
#   940,
#   20538,
#   14131,
#   281,
#   281,
#   1,
#   2219,
#   45,
#   307,
#   16,
#   14132,
#   1503,
#   1,
#   8213,
#   126],
#  [243, 41, 73, 39, 7, 137, 6, 628],
#  [1506, 157, 380, 472, 568, 26, 292, 262, 20539],
#  [140, 6, 12, 1, 27, 1465],
#  [184,
#   3,
#   4184,
#   5672,
#   2470,
#   10,
#   6630,
#   7,
#   2075,
#   404,
#   7324,
#   4,
#   404,
#   5673,
#   7324,
#   2,
#   296,
#   2,
#   8214,
#   217,
#   404,
#   7324,
#   1889,
#   42,
#   2470,
#   639,
#   4,
#   440,
#   12,
#   1,
#   7324,
#   404,
#   5673,
#   7324,
#   1889,
#   42,
#   639,
#   2470,
#   32,
#   1,
#   14133,
#   4,
#   1,
#   11168,
#   4964,
#   5,
#   9,
#   404,
#   87,
#   134,
#   2,
#   16,
#   2829,
#   449,
#   1,
#   24,
#   184,
#   3,
#   4184,
#   5672,
#   2470,
#   10,
#   6630,
#   73,
#   61,
#   58,
#   2419,
#   1,
#   5673,
#   2470,
#   32,
#   1,
#   7324,
#   14133,
#   4,
#   11168,
#   4964,
#   5,
#   9,
#   8,
#   5,
#   130,
#   101,
#   212,
#   7,
#   47,
#   48,
#   2,
#   170,
#   95,
#   17,
#   11,
#   47,
#   970,
#   1,
#   184,
#   2,
#   16,
#   220,
#   866,
#   4,
#   14134,
#   20,
#   1,
#   260,
#   7,
#   5292,
#   185,
#   5673,
#   5293,
#   5,
#   2470,
#   15,
#   53,
#   57,
#   24,
#   26,
#   136,
#   3,
#   125,
#   11168,
#   5293,
#   5,
#   2470,
#   82,
#   1,
#   2356,
#   838,
#   3,
#   4964,
#   5672,
#   34,
#   1,
#   83,
#   7,
#   219,
#   37,
#   61,
#   16,
#   185,
#   17,
#   86,
#   2676,
#   3,
#   565,
#   4964,
#   196,
#   9,
#   45,
#   719,
#   99,
#   13,
#   5,
#   130,
#   282,
#   184,
#   11,
#   193,
#   99,
#   470,
#   2,
#   1746,
#   1,
#   24,
#   150,
#   158,
#   1375,
#   4,
#   5673,
#   17,
#   7,
#   88,
#   20,
#   1,
#   2677,
#   995,
#   7,
#   47,
#   446,
#   3824,
#   1,
#   5673,
#   2470,
#   4,
#   1176,
#   73,
#   282,
#   1,
#   24,
#   867,
#   78,
#   4694,
#   32,
#   41,
#   22,
#   58,
#   231,
#   2,
#   96,
#   11,
#   2,
#   1146,
#   184,
#   694,
#   17,
#   7,
#   47,
#   48,
#   12,
#   42,
#   78,
#   58,
#   239,
#   80,
#   1,
#   404,
#   17,
#   5,
#   226,
#   3,
#   1,
#   24,
#   616],
#  [247,
#   860,
#   601,
#   178,
#   542,
#   562,
#   48,
#   21,
#   14135,
#   1298,
#   236,
#   167,
#   4,
#   91,
#   20540,
#   55,
#   587,
#   680,
#   21,
#   1747,
#   844,
#   76,
#   383,
#   105,
#   236,
#   11,
#   38,
#   700,
#   1930],
#  [346,
#   14136,
#   11169,
#   5,
#   3375,
#   324,
#   26,
#   7,
#   59,
#   70,
#   77,
#   130,
#   311,
#   12,
#   604,
#   77,
#   459,
#   4695,
#   2214,
#   460,
#   8215,
#   1,
#   346,
#   14137,
#   3,
#   1,
#   27,
#   19,
#   55,
#   1562,
#   20541,
#   2319,
#   896,
#   34,
#   309,
#   12,
#   1,
#   135,
#   226,
#   7,
#   47,
#   6081,
#   2076,
#   28,
#   20542,
#   77,
#   182,
#   124,
#   2,
#   2538,
#   13,
#   215,
#   8,
#   405,
#   26,
#   11,
#   87,
#   51,
#   16,
#   62,
#   56,
#   20543,
#   90,
#   34,
#   62,
#   163,
#   87,
#   20544,
#   10,
#   4,
#   33,
#   11,
#   1101,
#   391,
#   78,
#   1,
#   3148,
#   8215,
#   278,
#   130,
#   5,
#   11170,
#   330,
#   20545,
#   2,
#   3520,
#   20546,
#   10,
#   28,
#   161,
#   328,
#   22,
#   11,
#   3153,
#   74,
#   34,
#   5,
#   130,
#   635,
#   11171,
#   78,
#   368,
#   1147,
#   118,
#   77,
#   311,
#   12,
#   211,
#   51,
#   28,
#   202,
#   167,
#   15,
#   11,
#   488,
#   38],
#  [224,
#   333,
#   20547,
#   4,
#   224,
#   2,
#   30,
#   140,
#   6,
#   12,
#   21,
#   348,
#   7,
#   231,
#   6,
#   48,
#   1,
#   191,
#   4,
#   877,
#   2,
#   640,
#   63,
#   18,
#   62,
#   122,
#   9,
#   6,
#   193,
#   144,
#   802,
#   1,
#   752,
#   1110,
#   3,
#   30,
#   1175,
#   73,
#   2,
#   72,
#   5,
#   27,
#   4,
#   73,
#   2,
#   1962,
#   85,
#   73,
#   2,
#   483,
#   21,
#   115,
#   24,
#   197,
#   1,
#   24,
#   2830,
#   22,
#   6,
#   528,
#   904,
#   3,
#   352,
#   7,
#   231,
#   6,
#   854,
#   143,
#   63,
#   4,
#   86,
#   5,
#   895,
#   49,
#   576,
#   21,
#   943,
#   15,
#   149,
#   122,
#   197,
#   516,
#   971,
#   13,
#   45,
#   815,
#   1434,
#   21,
#   603,
#   4,
#   1,
#   437,
#   22,
#   6,
#   134,
#   137,
#   340,
#   76,
#   30,
#   245,
#   201,
#   36,
#   15,
#   28,
#   38,
#   27,
#   25,
#   201,
#   21,
#   212,
#   15,
#   13,
#   27,
#   4,
#   78,
#   191,
#   1652,
#   154,
#   1,
#   212,
#   126,
#   224],
#  [49,
#   1376,
#   32,
#   343,
#   790,
#   2,
#   30,
#   17,
#   6,
#   88,
#   2,
#   1994,
#   11,
#   8,
#   418,
#   222,
#   22,
#   6,
#   47,
#   48,
#   2,
#   1486,
#   80,
#   1,
#   667,
#   14138],
#  [13, 8, 28, 115, 1041, 3376, 10, 30],
#  [89,
#   26,
#   21,
#   1748,
#   233,
#   1087,
#   17,
#   5,
#   1628,
#   4,
#   29,
#   2033,
#   2267,
#   316,
#   5,
#   163,
#   187,
#   224,
#   38],
#  [89,
#   12,
#   1,
#   224,
#   89,
#   2749,
#   12,
#   1,
#   6082,
#   224,
#   7,
#   64,
#   9,
#   198,
#   7325,
#   19,
#   6083,
#   154,
#   15,
#   826,
#   1678,
#   425,
#   425,
#   3038,
#   20548,
#   4,
#   304,
#   46,
#   56,
#   145,
#   454,
#   169,
#   21,
#   27,
#   7,
#   64,
#   6,
#   1586,
#   136,
#   3,
#   1,
#   138,
#   2320,
#   17,
#   7,
#   33,
#   4,
#   7,
#   19,
#   5,
#   2118,
#   198,
#   7325,
#   45,
#   353,
#   2,
#   2119,
#   10,
#   1,
#   560,
#   22,
#   6,
#   337,
#   134,
#   5,
#   803,
#   20,
#   210,
#   221,
#   200,
#   2,
#   793,
#   36],
#  [7, 261, 37, 7, 190, 11],
#  [331,
#   1,
#   212,
#   8,
#   56,
#   3,
#   1679,
#   93,
#   3,
#   5294,
#   4,
#   58,
#   59,
#   19,
#   53,
#   14139,
#   34,
#   788,
#   3825,
#   65,
#   18,
#   7326,
#   3,
#   5294,
#   504,
#   425],
#  [5,
#   284,
#   43,
#   55,
#   618,
#   15,
#   8216,
#   20549,
#   1118,
#   9,
#   11,
#   16,
#   1349,
#   166,
#   32,
#   30,
#   13,
#   43,
#   55,
#   205,
#   67,
#   1,
#   24,
#   227,
#   2,
#   16,
#   35,
#   5,
#   215,
#   447,
#   3,
#   79,
#   679,
#   1445,
#   672,
#   25,
#   553,
#   177,
#   26,
#   11,
#   109,
#   14,
#   1074,
#   73,
#   25,
#   75,
#   1,
#   275,
#   8,
#   405,
#   9,
#   8,
#   75,
#   29,
#   24,
#   35,
#   9,
#   275,
#   61,
#   16,
#   567,
#   10,
#   30,
#   176,
#   1,
#   412,
#   12,
#   306,
#   108,
#   85,
#   9,
#   33,
#   14,
#   1995,
#   544,
#   87,
#   16,
#   166,
#   34,
#   53,
#   83,
#   49,
#   64,
#   1,
#   438,
#   12,
#   40,
#   8,
#   748,
#   902,
#   17,
#   405,
#   4,
#   22,
#   6,
#   39,
#   1074,
#   75,
#   1,
#   275,
#   3,
#   13,
#   24,
#   8,
#   405,
#   6,
#   87,
#   946,
#   1,
#   1989,
#   2,
#   33,
#   13,
#   170,
#   15,
#   1,
#   357,
#   3,
#   1,
#   27,
#   650,
#   1,
#   1010,
#   1711,
#   284,
#   4,
#   279,
#   5,
#   199,
#   15,
#   1,
#   819,
#   38,
#   27,
#   911,
#   21,
#   559,
#   49,
#   33,
#   14,
#   277,
#   1,
#   306,
#   108,
#   284,
#   146,
#   26,
#   59,
#   1743,
#   2,
#   170,
#   103,
#   2,
#   1,
#   24,
#   9,
#   47,
#   1565,
#   107,
#   2032,
#   544,
#   176,
#   1,
#   438,
#   12,
#   438,
#   15,
#   455,
#   1353,
#   3,
#   85,
#   6,
#   87,
#   113,
#   2,
#   340,
#   76,
#   198,
#   412,
#   12,
#   1509,
#   12,
#   553,
#   839,
#   12,
#   1829,
#   25,
#   12,
#   1487,
#   221,
#   200,
#   2,
#   279,
#   5,
#   199,
#   15,
#   28,
#   38,
#   27,
#   22,
#   6,
#   19,
#   53,
#   245,
#   35,
#   13,
#   38],
#  [634,
#   840,
#   601,
#   178,
#   2467,
#   7,
#   2608,
#   7327,
#   9,
#   6,
#   82,
#   4428,
#   74,
#   2539,
#   85,
#   7,
#   372,
#   6,
#   82,
#   892,
#   5674,
#   320,
#   20550,
#   89,
#   12,
#   1,
#   1418,
#   252,
#   2609,
#   9,
#   10,
#   538,
#   14140,
#   1851,
#   2678],
#  [289,
#   2,
#   2831,
#   1,
#   392,
#   3,
#   14141,
#   13,
#   8,
#   46,
#   3,
#   153,
#   1148,
#   129,
#   7,
#   69,
#   37,
#   5675,
#   31,
#   503,
#   912,
#   15,
#   321,
#   395,
#   1,
#   24,
#   43,
#   1,
#   11172,
#   1446,
#   34,
#   309,
#   1890,
#   14141,
#   15,
#   1,
#   6631,
#   25,
#   107,
#   20551,
#   7,
#   59,
#   68,
#   129,
#   9,
#   392,
#   858,
#   32,
#   536,
#   40,
#   52,
#   410,
#   5,
#   9383,
#   26,
#   11,
#   227,
#   2,
#   36,
#   9,
#   105,
#   569,
#   53,
#   1218,
#   701,
#   1,
#   2933,
#   1313,
#   20552,
#   9383,
#   14142,
#   1,
#   321,
#   20553,
#   15,
#   29,
#   14143,
#   4696,
#   2,
#   1,
#   6631,
#   6084,
#   107,
#   432,
#   1653,
#   10,
#   1,
#   1011,
#   11173,
#   66,
#   2679,
#   1,
#   2120,
#   20554,
#   1134,
#   208,
#   218,
#   1,
#   9383,
#   34,
#   1,
#   3039,
#   3,
#   20555,
#   9,
#   128,
#   2,
#   16,
#   1,
#   6085,
#   26,
#   7,
#   239,
#   2268,
#   107,
#   120,
#   117,
#   20556,
#   1,
#   7328,
#   20557,
#   20558,
#   1377,
#   11174,
#   4185,
#   20559,
#   4185,
#   672,
#   20560,
#   11174,
#   4185,
#   20561,
#   4185,
#   20562,
#   4185,
#   1111,
#   20563,
#   14144,
#   14145,
#   46,
#   208,
#   218,
#   168,
#   244,
#   15,
#   1,
#   6631,
#   34,
#   1,
#   3650,
#   5676,
#   1992,
#   1,
#   14146,
#   8,
#   320,
#   1,
#   3039,
#   26,
#   11,
#   8,
#   344,
#   2747,
#   15,
#   1,
#   6631,
#   13,
#   203,
#   94,
#   1447,
#   20564,
#   9,
#   18,
#   2121,
#   6632,
#   25,
#   11175,
#   25,
#   20565,
#   2220,
#   14147,
#   536,
#   109,
#   11,
#   1447,
#   217,
#   48,
#   179,
#   20566,
#   4,
#   14148,
#   491,
#   220,
#   3,
#   54,
#   19,
#   1781,
#   20567,
#   3377,
#   536,
#   109,
#   11,
#   1447,
#   4184,
#   9384,
#   2168,
#   4,
#   71,
#   214,
#   71,
#   913,
#   164,
#   13,
#   8,
#   42,
#   51,
#   14149,
#   38],
#  [4965,
#   8217,
#   582,
#   282,
#   145,
#   1,
#   20568,
#   5295,
#   1782,
#   23,
#   7329,
#   210,
#   101,
#   9,
#   50,
#   2540,
#   15,
#   1,
#   275,
#   43,
#   282,
#   55,
#   20569,
#   31,
#   1931,
#   20570,
#   395,
#   3154,
#   150,
#   1,
#   709,
#   31,
#   20571,
#   4,
#   31,
#   20572,
#   4,
#   20573,
#   696,
#   17,
#   420,
#   110,
#   7,
#   47,
#   1713,
#   1963,
#   9,
#   8217,
#   20574,
#   14,
#   16,
#   696],
#  [5,
#   628,
#   31,
#   5,
#   1824,
#   13,
#   8,
#   5,
#   1026,
#   188,
#   22,
#   30,
#   130,
#   8,
#   20575,
#   78,
#   75,
#   8,
#   1,
#   5296,
#   14150,
#   27,
#   186,
#   53,
#   2750,
#   283,
#   2471,
#   58,
#   42,
#   68,
#   2541,
#   3651,
#   3,
#   2077,
#   8,
#   14,
#   1,
#   3984,
#   1378,
#   3,
#   2541,
#   2420,
#   26,
#   1,
#   27,
#   8,
#   14,
#   750,
#   2,
#   339,
#   1,
#   543,
#   3254,
#   77,
#   845,
#   450,
#   524,
#   9385,
#   322,
#   1,
#   20576,
#   587,
#   8,
#   268,
#   598,
#   4,
#   44,
#   71,
#   14,
#   781,
#   46,
#   596,
#   8,
#   471,
#   17,
#   3378,
#   845,
#   342,
#   7,
#   45,
#   16,
#   11176,
#   1,
#   1510,
#   2,
#   170,
#   62,
#   1488,
#   32,
#   1,
#   781,
#   587,
#   381,
#   53,
#   537],
#  [25, 184, 3, 6086, 20577],
#  [268,
#   80,
#   947,
#   12,
#   121,
#   14151,
#   14152,
#   1316,
#   481,
#   13,
#   525,
#   87,
#   16,
#   166,
#   89,
#   12,
#   1448,
#   121,
#   14151,
#   14152,
#   1316,
#   481,
#   7,
#   423,
#   1,
#   2221,
#   27,
#   2610,
#   9,
#   1,
#   121,
#   8,
#   86,
#   128,
#   176,
#   268,
#   80,
#   26,
#   41,
#   8,
#   44,
#   645,
#   25,
#   947,
#   17,
#   2,
#   75,
#   107,
#   80,
#   10,
#   30,
#   85,
#   2751,
#   268,
#   80,
#   84,
#   6,
#   80,
#   5,
#   3255,
#   268,
#   80,
#   284,
#   114,
#   17,
#   268,
#   80,
#   25,
#   268,
#   80,
#   10,
#   24,
#   117,
#   6,
#   266,
#   66,
#   280,
#   76,
#   15,
#   1,
#   121,
#   795,
#   27,
#   5,
#   455,
#   645,
#   25,
#   947,
#   12,
#   75,
#   197,
#   13,
#   121,
#   10,
#   382,
#   24,
#   8,
#   2611,
#   20,
#   268,
#   80,
#   49,
#   100,
#   2,
#   1,
#   121,
#   795,
#   27,
#   4,
#   72,
#   11,
#   2,
#   441,
#   5,
#   268,
#   80,
#   947,
#   22,
#   6,
#   19,
#   742,
#   57,
#   268,
#   80,
#   400,
#   410,
#   1266,
#   9,
#   6,
#   19,
#   1749,
#   1,
#   268,
#   80,
#   947,
#   15,
#   153,
#   122,
#   165,
#   6,
#   39,
#   144,
#   5,
#   184,
#   3,
#   2221,
#   122,
#   6,
#   19,
#   646,
#   31,
#   1852,
#   15,
#   1,
#   28,
#   348,
#   173,
#   11,
#   8,
#   1629,
#   34,
#   1,
#   106,
#   357,
#   3,
#   53,
#   30,
#   27,
#   84,
#   6,
#   18,
#   1417,
#   10,
#   4,
#   78,
#   2832,
#   121,
#   32,
#   1,
#   3155,
#   1027,
#   199,
#   9,
#   53,
#   268,
#   80,
#   327,
#   2472,
#   114,
#   29,
#   645,
#   45,
#   16,
#   166,
#   46,
#   692,
#   145,
#   52,
#   19,
#   55,
#   742,
#   17,
#   1090,
#   15,
#   412,
#   12,
#   306,
#   108,
#   22,
#   6,
#   19,
#   53,
#   245,
#   49,
#   201,
#   95,
#   34,
#   1,
#   400,
#   269,
#   245,
#   27,
#   140,
#   6],
#  [84,
#   7,
#   258,
#   1,
#   1485,
#   217,
#   9,
#   134,
#   2,
#   16,
#   190,
#   6,
#   59,
#   19,
#   2,
#   162,
#   12,
#   20578,
#   334,
#   6,
#   51,
#   299,
#   1,
#   217,
#   253,
#   398,
#   22,
#   6,
#   20579,
#   2,
#   655,
#   1,
#   312,
#   1,
#   184,
#   8,
#   253,
#   41,
#   51,
#   710,
#   1,
#   9386,
#   22,
#   14,
#   105,
#   78,
#   607],
#  [9,
#   250,
#   973,
#   709,
#   14153,
#   12,
#   36,
#   17,
#   105,
#   15,
#   20580,
#   230,
#   11,
#   203,
#   130,
#   1680,
#   36,
#   7,
#   205,
#   254,
#   323,
#   36,
#   68],
#  [71,
#   14,
#   214,
#   9,
#   1,
#   20581,
#   4186,
#   356,
#   8,
#   168,
#   151,
#   298,
#   934,
#   1397,
#   2680,
#   662,
#   1508,
#   178],
#  [49,
#   33,
#   14,
#   749,
#   122,
#   17,
#   6,
#   88,
#   20,
#   13,
#   72,
#   2,
#   20582,
#   20583,
#   20584,
#   22,
#   6,
#   353,
#   2,
#   33,
#   37,
#   6,
#   45,
#   16,
#   181,
#   32,
#   143,
#   14154,
#   4697],
#  [9, 8, 42, 7, 201, 12, 91],
#  [4, 7330, 3521, 1607, 36],
#  [49,
#   33,
#   6,
#   19,
#   2,
#   1630,
#   21,
#   83,
#   2,
#   722,
#   943,
#   48,
#   13,
#   46,
#   7,
#   39,
#   3985,
#   2,
#   362,
#   32,
#   195,
#   531,
#   10,
#   46,
#   2833,
#   3522,
#   2678,
#   6087,
#   3523],
#  [7,
#   39,
#   100,
#   15,
#   1449,
#   20,
#   136,
#   57,
#   2222,
#   232,
#   13,
#   1681,
#   1219,
#   474,
#   11177,
#   2612,
#   2473],
#  [13,
#   465,
#   2034,
#   8,
#   20585,
#   17,
#   1,
#   3379,
#   15,
#   5,
#   1654,
#   18,
#   855,
#   2,
#   1850,
#   249,
#   1028,
#   25,
#   8218,
#   40,
#   58,
#   877,
#   2,
#   424,
#   9,
#   716,
#   43,
#   575,
#   2,
#   33,
#   20,
#   40,
#   8,
#   855,
#   31,
#   9,
#   716,
#   31,
#   753,
#   11,
#   3380,
#   46,
#   8,
#   20586,
#   2,
#   1265,
#   681,
#   1,
#   944,
#   1149,
#   1,
#   1627,
#   3,
#   3040,
#   17,
#   5,
#   1654,
#   716,
#   8,
#   855,
#   2,
#   7331,
#   29,
#   406,
#   9,
#   3,
#   9387,
#   4,
#   321,
#   4698,
#   4,
#   9388,
#   11,
#   43,
#   262,
#   2,
#   33,
#   20,
#   86,
#   635,
#   4,
#   6633,
#   449,
#   1,
#   1682,
#   3,
#   5,
#   716,
#   9,
#   8,
#   5,
#   14155,
#   4,
#   2122,
#   722,
#   559,
#   2,
#   1489,
#   3826,
#   18,
#   3652,
#   855,
#   2,
#   3986,
#   676,
#   1028,
#   4,
#   52,
#   80,
#   327,
#   4,
#   3379,
#   48,
#   42,
#   57,
#   2321,
#   3,
#   9389,
#   2,
#   33,
#   13,
#   765,
#   1,
#   80,
#   3,
#   3040,
#   15,
#   5,
#   1654,
#   8,
#   10,
#   44,
#   116,
#   29,
#   807,
#   2,
#   1025,
#   56,
#   635,
#   4,
#   6633,
#   26,
#   271,
#   5,
#   116,
#   2,
#   2474,
#   6,
#   14156],
#  [5677,
#   1853,
#   629,
#   21,
#   110,
#   12,
#   114,
#   702,
#   9,
#   60,
#   1248,
#   3,
#   60,
#   317,
#   2421,
#   9,
#   50,
#   23,
#   5,
#   1932,
#   9,
#   8,
#   321,
#   395,
#   1,
#   297,
#   9,
#   50,
#   23,
#   5,
#   9390,
#   4966,
#   8,
#   1220,
#   216,
#   1,
#   297,
#   9,
#   50,
#   23,
#   1932,
#   8,
#   7332],
#  [60,
#   117,
#   23,
#   11178,
#   20587,
#   14,
#   11178,
#   14157,
#   7,
#   69,
#   454,
#   34,
#   60,
#   6634,
#   14158,
#   2417,
#   151,
#   91,
#   7,
#   66,
#   19,
#   60,
#   6634,
#   5678,
#   2078,
#   20,
#   189,
#   20588,
#   1,
#   450,
#   23,
#   5,
#   325,
#   2834,
#   10,
#   1,
#   2835,
#   241,
#   325,
#   337,
#   7,
#   487,
#   69,
#   5,
#   2357,
#   174,
#   1504,
#   6088,
#   1996,
#   3,
#   1930,
#   32,
#   20589],
#  [1630,
#   3,
#   83,
#   868,
#   9391,
#   12,
#   1,
#   14159,
#   8,
#   906,
#   14,
#   9391,
#   12,
#   1,
#   14160,
#   11179,
#   155],
#  [331,
#   1,
#   500,
#   135,
#   20590,
#   116,
#   2,
#   1488,
#   1,
#   24,
#   10,
#   466,
#   687,
#   7333,
#   238,
#   47,
#   16,
#   2,
#   1997,
#   149,
#   3,
#   20591,
#   7334,
#   9,
#   571,
#   1,
#   14161,
#   3041,
#   102,
#   50,
#   4,
#   8219,
#   3653,
#   1,
#   14162,
#   52,
#   47,
#   19,
#   4429,
#   95,
#   1928,
#   428,
#   948,
#   17,
#   729,
#   17,
#   1,
#   8220,
#   558,
#   50,
#   47,
#   19,
#   2934,
#   13,
#   17,
#   5,
#   3654,
#   720,
#   1056,
#   316,
#   1215,
#   5679,
#   3,
#   2422,
#   3,
#   3156,
#   1655,
#   1056,
#   1,
#   14163,
#   3,
#   14164,
#   4,
#   304,
#   1056,
#   5,
#   1714,
#   3145,
#   1608,
#   3987,
#   9392,
#   4,
#   6635,
#   7335,
#   7,
#   69,
#   2475,
#   6,
#   45,
#   1997,
#   1,
#   158,
#   1715,
#   495,
#   1744,
#   20,
#   13,
#   4,
#   9,
#   6,
#   45,
#   3042,
#   1,
#   1511,
#   10,
#   1,
#   1891],
#  [816,
#   11,
#   23,
#   5297,
#   31,
#   4,
#   60,
#   2358,
#   10,
#   1,
#   115,
#   191,
#   71,
#   289,
#   2,
#   393,
#   11,
#   2,
#   1,
#   116,
#   11,
#   23,
#   154,
#   52,
#   1830,
#   11,
#   10,
#   1165,
#   1716,
#   2681,
#   7336,
#   4430],
#  [20592,
#   20593,
#   20594,
#   8,
#   5,
#   409,
#   378,
#   39,
#   6,
#   2836,
#   11,
#   475,
#   11,
#   8,
#   1484,
#   456,
#   527,
#   39,
#   6,
#   118,
#   11,
#   8,
#   254],
#  [89,
#   12,
#   8221,
#   36,
#   3,
#   13,
#   314,
#   7,
#   1029,
#   28,
#   14165,
#   17,
#   1,
#   831,
#   3,
#   5,
#   4967,
#   2542,
#   5,
#   250,
#   216,
#   171],
#  [7, 2613, 5, 237, 10, 1512, 2752, 2, 1, 837, 7337, 7, 1831, 58, 39, 81, 231],
#  [1203,
#   367,
#   13,
#   367,
#   8,
#   4968,
#   32,
#   38,
#   1432,
#   775,
#   2217,
#   2322,
#   14166,
#   6089,
#   1,
#   72,
#   173,
#   12,
#   13,
#   131,
#   39,
#   16,
#   128,
#   2,
#   170,
#   238,
#   2,
#   1,
#   367,
#   2837,
#   54,
#   34,
#   320,
#   1435,
#   894,
#   1135,
#   83,
#   15,
#   841,
#   87,
#   636,
#   6,
#   61,
#   199,
#   54,
#   83,
#   7338,
#   11,
#   8,
#   1121,
#   2,
#   84,
#   11,
#   288,
#   1135,
#   83,
#   25,
#   194,
#   322,
#   51,
#   209,
#   1,
#   83,
#   10,
#   178,
#   62,
#   283,
#   18,
#   10,
#   1,
#   254,
#   1148,
#   67,
#   11,
#   562,
#   48,
#   62,
#   702,
#   18,
#   1216,
#   13,
#   8,
#   1,
#   996,
#   10,
#   1,
#   411,
#   702,
#   2223,
#   1656,
#   32,
#   4969,
#   1379,
#   5,
#   14167,
#   7339,
#   563,
#   17,
#   1,
#   2323,
#   2753,
#   5,
#   100,
#   320,
#   473,
#   248,
#   563,
#   2,
#   1,
#   457,
#   3,
#   1,
#   519,
#   3655,
#   4970,
#   6636,
#   763,
#   2614,
#   105,
#   154,
#   1,
#   2323,
#   119,
#   5,
#   1832,
#   335,
#   473,
#   248,
#   2614,
#   2,
#   1,
#   457,
#   3,
#   1,
#   519,
#   4,
#   66,
#   3,
#   1,
#   1998,
#   3043,
#   1512,
#   3,
#   1,
#   14168,
#   6090,
#   1705,
#   808,
#   3,
#   1,
#   2269,
#   2543,
#   3524,
#   3,
#   775,
#   20595,
#   665,
#   20,
#   20596,
#   9393,
#   490,
#   20597,
#   14169,
#   5,
#   2754,
#   15,
#   396,
#   1330,
#   636,
#   34,
#   1,
#   14168,
#   1329,
#   10,
#   9394,
#   129,
#   52,
#   2755,
#   5,
#   14170,
#   2,
#   4431,
#   6637,
#   9,
#   2476,
#   3,
#   1,
#   2477,
#   2359,
#   1066,
#   4,
#   11180,
#   11181,
#   3,
#   7340,
#   656,
#   52,
#   66,
#   6091,
#   1,
#   7341,
#   630,
#   16,
#   119,
#   56,
#   4971,
#   31,
#   2123,
#   11,
#   2,
#   1,
#   400,
#   271,
#   93,
#   3157,
#   6638,
#   10,
#   4187,
#   298,
#   1,
#   248,
#   1705,
#   8,
#   10,
#   1,
#   254,
#   191,
#   25,
#   13,
#   373,
#   130,
#   8,
#   1216,
#   1,
#   2615,
#   3,
#   2831,
#   18,
#   5298,
#   17,
#   2,
#   402,
#   11,
#   8,
#   428,
#   115,
#   25,
#   5299,
#   115,
#   287,
#   730,
#   189,
#   820,
#   4970,
#   14171,
#   763,
#   4,
#   1933,
#   11182,
#   3988,
#   6092,
#   52,
#   61,
#   16,
#   428,
#   115,
#   4,
#   5299,
#   273,
#   25,
#   3381,
#   5300,
#   26,
#   14,
#   220,
#   62,
#   3,
#   1,
#   283,
#   1505,
#   1631,
#   248,
#   662,
#   8,
#   913,
#   1,
#   437,
#   54,
#   23,
#   87,
#   396,
#   1091,
#   1,
#   1297,
#   3,
#   1,
#   27,
#   288,
#   11,
#   23,
#   273,
#   2075,
#   15,
#   9,
#   291,
#   248,
#   846,
#   8,
#   5,
#   3989,
#   2270,
#   4,
#   8,
#   913,
#   42,
#   103,
#   1267,
#   75,
#   8,
#   11,
#   1042,
#   2,
#   5,
#   4188,
#   5680,
#   10,
#   11183,
#   248,
#   796,
#   8,
#   913,
#   1,
#   437,
#   1057,
#   1053,
#   1091,
#   41,
#   8,
#   5,
#   4432,
#   10,
#   1,
#   378,
#   15,
#   248,
#   554,
#   11,
#   61,
#   118,
#   7342,
#   1040,
#   396,
#   4433,
#   10,
#   1432,
#   775,
#   2217,
#   4188,
#   5680,
#   10,
#   9394,
#   14,
#   3656,
#   1040,
#   634,
#   4433,
#   248,
#   617,
#   8,
#   913,
#   1,
#   2544,
#   1,
#   3256,
#   4,
#   1,
#   437,
#   796,
#   935,
#   601,
#   248,
#   1054,
#   8,
#   913,
#   1,
#   437,
#   617,
#   87,
#   636,
#   248,
#   1234,
#   8,
#   913,
#   1,
#   883,
#   11184,
#   20598,
#   15,
#   248,
#   1397,
#   170,
#   1,
#   883,
#   298,
#   17,
#   3257,
#   7343,
#   3158,
#   25,
#   2838,
#   20599,
#   20600,
#   11185,
#   20601,
#   6093,
#   20602,
#   8222,
#   1267,
#   6,
#   19,
#   1,
#   254,
#   378,
#   11,
#   61,
#   16,
#   1432,
#   8223,
#   2322,
#   861,
#   20603,
#   4434,
#   248,
#   1892,
#   8,
#   913,
#   1,
#   883,
#   11186,
#   9395,
#   1,
#   2270,
#   12,
#   248,
#   2271,
#   1964,
#   2,
#   1,
#   878,
#   4972,
#   4,
#   14,
#   40,
#   11,
#   23,
#   1609,
#   2,
#   173,
#   2,
#   248,
#   3657,
#   8,
#   913,
#   1,
#   437,
#   1057,
#   87,
#   636,
#   248,
#   1043,
#   8,
#   913,
#   1,
#   437,
#   247,
#   860,
#   636,
#   248,
#   2839,
#   8,
#   913,
#   1,
#   883,
#   20604,
#   4435,
#   4,
#   1,
#   437,
#   974,
#   87,
#   636,
#   1,
#   2270,
#   12,
#   248,
#   2353,
#   43,
#   5,
#   588,
#   234,
#   2,
#   248,
#   2271,
#   248,
#   2423,
#   8,
#   913,
#   1,
#   883,
#   20605,
#   20606,
#   248,
#   3258,
#   8,
#   913,
#   1,
#   437,
#   1249,
#   1053,
#   1091,
#   248,
#   2272,
#   8,
#   913,
#   1,
#   883,
#   20607,
#   763,
#   248,
#   2035,
#   8,
#   913,
#   1,
#   883,
#   20608,
#   5681,
#   248,
#   5682,
#   8,
#   913,
#   1,
#   883,
#   20609,
#   4699,
#   4,
#   1,
#   437,
#   1249,
#   1053,
#   1091,
#   248,
#   1513,
#   8,
#   5,
#   3989,
#   2270,
#   4,
#   8,
#   913,
#   42,
#   103,
#   248,
#   3044,
#   8,
#   913,
#   1,
#   437,
#   833,
#   87,
#   636],
#  [66, 7344, 2478, 20610],
#  [18,
#   6,
#   366,
#   1533,
#   1610,
#   49,
#   33,
#   14,
#   299,
#   177,
#   32,
#   85,
#   15,
#   30,
#   17,
#   6,
#   88,
#   2,
#   9396,
#   2479,
#   766,
#   21,
#   132,
#   764,
#   2,
#   16,
#   222,
#   4,
#   19,
#   55,
#   326,
#   22,
#   6,
#   47,
#   48,
#   2,
#   1486,
#   49,
#   80,
#   30,
#   667,
#   12,
#   784,
#   132,
#   140,
#   6,
#   3990,
#   1610,
#   1610,
#   40,
#   1,
#   97,
#   8,
#   21,
#   234,
#   88,
#   6,
#   94,
#   147,
#   40,
#   7,
#   166,
#   1610,
#   1610,
#   33,
#   6,
#   68,
#   40,
#   1,
#   293,
#   1893,
#   417,
#   1610,
#   1610,
#   1893,
#   109,
#   14,
#   270,
#   524,
#   35,
#   1,
#   14172,
#   8224,
#   25,
#   40,
#   2424,
#   1,
#   1112,
#   11,
#   8,
#   5,
#   1893,
#   8,
#   5,
#   509,
#   3,
#   1,
#   1112,
#   1610,
#   1610,
#   147,
#   868,
#   10,
#   1,
#   1893,
#   131,
#   3,
#   9396,
#   151,
#   91,
#   6,
#   366,
#   5683,
#   4,
#   371,
#   36,
#   22,
#   11,
#   130,
#   1750,
#   176,
#   1,
#   131,
#   1893,
#   25,
#   53,
#   57,
#   131,
#   11,
#   562,
#   56,
#   48,
#   2545,
#   397,
#   54,
#   18,
#   4436,
#   4,
#   61,
#   16,
#   166,
#   17,
#   515,
#   148,
#   9397,
#   1610,
#   1610,
#   1200,
#   29,
#   303,
#   1534,
#   97,
#   32,
#   1,
#   9396,
#   148,
#   27,
#   1610,
#   1610,
#   1,
#   766,
#   2360,
#   3658,
#   1,
#   2840,
#   54,
#   81,
#   2935,
#   17,
#   29,
#   2036,
#   20611,
#   10,
#   2936,
#   2,
#   20612,
#   3659,
#   54,
#   4700,
#   34,
#   1568,
#   1,
#   11187,
#   8225,
#   15,
#   107,
#   4701,
#   4,
#   1,
#   5684,
#   758,
#   1632,
#   2,
#   255,
#   95,
#   1610,
#   1610,
#   9,
#   8,
#   14,
#   1657,
#   4,
#   43,
#   262,
#   2,
#   33,
#   20,
#   1,
#   1893,
#   1610,
#   1610,
#   1450,
#   366,
#   3159,
#   148,
#   8,
#   508,
#   3,
#   366,
#   9398,
#   1610,
#   1610,
#   299,
#   9,
#   723,
#   1610],
#  [222,
#   333,
#   39,
#   6,
#   49,
#   167,
#   5,
#   162,
#   150,
#   13,
#   206,
#   577,
#   30,
#   484,
#   687,
#   1587,
#   1965,
#   378,
#   90,
#   38,
#   20613,
#   14173,
#   180],
#  [40,
#   33,
#   6,
#   410,
#   1024,
#   110,
#   10,
#   13,
#   849,
#   204,
#   1201,
#   1,
#   678,
#   20614,
#   4973,
#   10,
#   14174,
#   6639,
#   4,
#   2756,
#   54,
#   18,
#   1024,
#   110,
#   12,
#   4437,
#   869,
#   1,
#   779,
#   3,
#   14174,
#   8226,
#   9399,
#   6094,
#   4,
#   60,
#   14175,
#   2324,
#   20,
#   1150,
#   82,
#   3525,
#   499,
#   32,
#   60,
#   893,
#   4438,
#   110,
#   7,
#   19,
#   44,
#   406,
#   40,
#   110,
#   20615,
#   4,
#   20616,
#   128,
#   7,
#   239,
#   201,
#   95,
#   126,
#   44,
#   57,
#   2546,
#   43,
#   4702,
#   1,
#   2361,
#   3,
#   92,
#   2841,
#   54,
#   227,
#   2,
#   36,
#   2,
#   16,
#   1,
#   701,
#   3,
#   5,
#   1999,
#   355],
#  [3259, 310, 542, 20617],
#  [238,
#   31,
#   6,
#   4,
#   195,
#   240,
#   15,
#   28,
#   657,
#   4,
#   11188,
#   18,
#   66,
#   20618,
#   1451,
#   15,
#   177,
#   49,
#   4],
#  [1, 6640, 59, 1658, 41, 316, 11, 927, 2547, 223, 4, 416],
#  [6,
#   18,
#   91,
#   5,
#   2837,
#   333,
#   21,
#   338,
#   43,
#   55,
#   2842,
#   1,
#   2837,
#   9400,
#   3045,
#   6,
#   2,
#   367,
#   57,
#   7345,
#   132,
#   15,
#   654,
#   3991,
#   122,
#   2480,
#   408,
#   66,
#   476,
#   17,
#   3991,
#   1465,
#   8,
#   495,
#   9401,
#   5,
#   158,
#   1044,
#   2616,
#   11189,
#   2,
#   457,
#   700,
#   860,
#   636,
#   4974,
#   39,
#   367,
#   132,
#   119,
#   31,
#   315,
#   65,
#   18,
#   14,
#   9402,
#   2,
#   85,
#   618,
#   176,
#   2480,
#   408,
#   2480,
#   408,
#   8,
#   2000,
#   2,
#   81,
#   5,
#   695,
#   392,
#   3,
#   85,
#   2471,
#   2,
#   73,
#   1717,
#   1465,
#   8,
#   2000,
#   26,
#   10,
#   5,
#   56,
#   3653,
#   116,
#   12,
#   1,
#   2616,
#   1,
#   184,
#   3,
#   85,
#   20,
#   2480,
#   408,
#   6641,
#   367,
#   8,
#   1629,
#   34,
#   936,
#   14176,
#   12,
#   1,
#   1354,
#   15,
#   2124,
#   64,
#   30,
#   2124,
#   86,
#   2842,
#   2837,
#   754,
#   203,
#   237,
#   73,
#   6,
#   39,
#   72,
#   85,
#   94,
#   20,
#   2480,
#   408,
#   1,
#   433,
#   137,
#   27,
#   15,
#   2480,
#   408,
#   39,
#   16,
#   292,
#   63,
#   4,
#   1,
#   433,
#   223,
#   12,
#   1,
#   2616,
#   39,
#   16,
#   292,
#   63,
#   22,
#   6,
#   33,
#   14,
#   113,
#   13,
#   9400,
#   6,
#   87,
#   201,
#   53,
#   794,
#   2,
#   277,
#   11,
#   12,
#   6,
#   34,
#   53,
#   83,
#   376],
#  [1377,
#   187,
#   1,
#   46,
#   4189,
#   15,
#   73,
#   315,
#   4189,
#   15,
#   1,
#   27,
#   18,
#   20619,
#   8227,
#   4,
#   6,
#   296,
#   2,
#   1452,
#   13,
#   3526,
#   425,
#   490,
#   15,
#   36,
#   187,
#   51,
#   17,
#   1659,
#   17,
#   505,
#   401,
#   55,
#   4,
#   7,
#   231,
#   6,
#   1040,
#   10,
#   5,
#   14177,
#   2214],
#  [180, 20620, 657, 1377, 7, 1331, 40, 6622, 42, 1, 657],
#  [1283, 13, 24, 61, 130, 16, 3660, 20, 1, 1264, 2125, 14178, 6642, 7, 68, 38],
#  [507,
#   7,
#   23,
#   9403,
#   9,
#   50,
#   104,
#   494,
#   123,
#   334,
#   9,
#   47,
#   137,
#   1,
#   24,
#   91,
#   9,
#   50,
#   43,
#   2682,
#   7,
#   19,
#   44,
#   354,
#   134,
#   25,
#   1934,
#   2,
#   6095,
#   20,
#   157],
#  [7,
#   681,
#   1,
#   1418,
#   3046,
#   7,
#   59,
#   70,
#   29,
#   1676,
#   47,
#   1718,
#   34,
#   13,
#   83,
#   169,
#   1933,
#   3,
#   28,
#   132,
#   18,
#   3382,
#   4,
#   1,
#   587,
#   1611,
#   9,
#   29,
#   240,
#   318,
#   56,
#   9404,
#   10,
#   92,
#   348,
#   22,
#   7,
#   337,
#   70,
#   9,
#   7,
#   19,
#   1,
#   348,
#   9,
#   47,
#   20621,
#   587,
#   359,
#   252,
#   1147,
#   162,
#   6,
#   74,
#   12,
#   5,
#   7346,
#   14179],
#  [4,
#   84,
#   195,
#   4703,
#   20622,
#   595,
#   75,
#   1,
#   572,
#   12,
#   1,
#   9405,
#   48,
#   14180,
#   305,
#   2757,
#   20623,
#   136,
#   20,
#   44,
#   359,
#   23,
#   2843,
#   20,
#   44,
#   51,
#   5685,
#   7,
#   664,
#   2001,
#   9,
#   12,
#   62,
#   1,
#   895,
#   1,
#   20624,
#   1299,
#   8,
#   5,
#   191,
#   271,
#   93,
#   767,
#   822,
#   1030,
#   25,
#   164,
#   329,
#   30,
#   47,
#   16,
#   5,
#   139,
#   194,
#   191,
#   22,
#   5685,
#   663,
#   820,
#   72,
#   192,
#   614,
#   164,
#   329,
#   57,
#   93,
#   4703,
#   7347],
#  [22, 58, 11190, 9, 149, 47, 16, 486, 2, 968, 1283],
#  [75,
#   1854,
#   4,
#   1284,
#   10,
#   1,
#   383,
#   241,
#   109,
#   14,
#   14181,
#   1,
#   539,
#   3,
#   5,
#   101,
#   30,
#   15,
#   1,
#   496,
#   11191,
#   2001,
#   9,
#   67,
#   1,
#   383,
#   241,
#   43,
#   14,
#   322,
#   14182,
#   76,
#   1,
#   543,
#   35,
#   1,
#   20625,
#   11,
#   8,
#   599,
#   1783,
#   12,
#   228,
#   2,
#   68,
#   1,
#   543,
#   4,
#   765,
#   1783,
#   12,
#   228,
#   2,
#   280,
#   35,
#   11,
#   7,
#   2844,
#   114,
#   5,
#   3992,
#   7,
#   70,
#   11,
#   8,
#   1157,
#   26,
#   387,
#   436,
#   2,
#   280,
#   5,
#   1005,
#   30,
#   24,
#   35,
#   5,
#   496,
#   9,
#   8,
#   14183,
#   4,
#   25,
#   1058,
#   129,
#   136,
#   30,
#   192,
#   96,
#   11,
#   254,
#   8,
#   9,
#   52,
#   219,
#   503,
#   805,
#   8,
#   2,
#   589,
#   1,
#   543,
#   13,
#   8,
#   254,
#   503,
#   805,
#   8,
#   14,
#   2,
#   589,
#   1,
#   543,
#   2758,
#   67,
#   11,
#   8,
#   1157,
#   2,
#   2481,
#   40,
#   1,
#   543,
#   8,
#   53,
#   807,
#   2,
#   33,
#   9,
#   8,
#   321,
#   395,
#   389,
#   3,
#   543,
#   30,
#   4704,
#   12,
#   1894,
#   209,
#   5,
#   249,
#   116,
#   30,
#   8,
#   2617,
#   2,
#   3661,
#   1,
#   339,
#   3,
#   758,
#   530,
#   4,
#   328,
#   14,
#   198,
#   1092,
#   26,
#   153,
#   3,
#   265,
#   110,
#   22,
#   1,
#   543,
#   8,
#   347,
#   4,
#   6096,
#   11,
#   8,
#   1300,
#   12,
#   228,
#   2,
#   589,
#   9,
#   22,
#   1,
#   543,
#   8,
#   14183,
#   4,
#   1058,
#   11,
#   8,
#   56,
#   4975,
#   26,
#   436,
#   12,
#   228,
#   2,
#   589,
#   15,
#   40,
#   249,
#   265,
#   110,
#   1995,
#   4,
#   70,
#   35,
#   5,
#   496,
#   94,
#   22,
#   125,
#   265,
#   110,
#   586,
#   129,
#   30,
#   192,
#   96,
#   150,
#   1268,
#   8,
#   84,
#   52,
#   482,
#   11192,
#   20,
#   46,
#   608,
#   3,
#   5,
#   1284,
#   4,
#   5686,
#   9,
#   1,
#   608,
#   9,
#   52,
#   19,
#   2845,
#   3527,
#   1,
#   543,
#   4,
#   14,
#   51,
#   46,
#   2355,
#   25,
#   416,
#   15,
#   1,
#   496,
#   34,
#   803,
#   7,
#   19,
#   55,
#   289,
#   2,
#   1535,
#   13,
#   605,
#   6097,
#   3047,
#   26,
#   11,
#   8,
#   1157,
#   2,
#   33,
#   37,
#   10,
#   1,
#   9406,
#   3,
#   5,
#   1503,
#   11193,
#   809,
#   308,
#   1,
#   158,
#   1833,
#   631,
#   8,
#   67,
#   62,
#   315,
#   14184,
#   4,
#   20626,
#   59,
#   113,
#   2,
#   557,
#   10,
#   156,
#   52,
#   113,
#   228,
#   2,
#   261,
#   20,
#   92,
#   416,
#   211,
#   14,
#   149,
#   35,
#   1,
#   605,
#   132,
#   211,
#   75,
#   7,
#   2362,
#   32,
#   1,
#   149,
#   35,
#   1,
#   590,
#   3,
#   1,
#   24,
#   8228],
#  [13, 1100, 562, 34, 984, 11194, 839, 4, 11195, 9, 52, 87, 19, 1122, 2548],
#  [66, 4705, 16, 313, 22, 6, 104, 628, 2, 13, 15, 28, 38, 27],
#  [4439,
#   870,
#   2680,
#   823,
#   175,
#   343,
#   1,
#   4439,
#   20,
#   1,
#   14185,
#   11196,
#   5301,
#   4976,
#   65,
#   14186,
#   10,
#   1,
#   859,
#   3048,
#   2,
#   13,
#   27,
#   5301,
#   4976,
#   4,
#   20627,
#   20628,
#   18,
#   249,
#   2323,
#   2318,
#   1055,
#   188,
#   185,
#   31,
#   1705,
#   3249,
#   6098,
#   2683],
#  [28,
#   238,
#   18,
#   86,
#   407,
#   74,
#   2,
#   2425,
#   260,
#   7,
#   19,
#   44,
#   406,
#   40,
#   29,
#   3827,
#   8,
#   536,
#   528,
#   2,
#   1630,
#   53,
#   56,
#   83,
#   20,
#   6,
#   107,
#   347,
#   21,
#   81,
#   961,
#   63,
#   8,
#   2,
#   6099,
#   1,
#   4977,
#   141,
#   6,
#   18,
#   3049,
#   32,
#   1,
#   276,
#   407,
#   17,
#   21,
#   161,
#   27,
#   5302,
#   7,
#   446,
#   6,
#   70,
#   282,
#   4,
#   619,
#   75,
#   6,
#   246,
#   63,
#   17,
#   13,
#   191,
#   61,
#   81,
#   16,
#   12,
#   153,
#   18,
#   574,
#   15,
#   1751],
#  [724,
#   4,
#   11,
#   104,
#   66,
#   130,
#   1885,
#   76,
#   264,
#   495,
#   14187,
#   3,
#   1,
#   275,
#   334,
#   182,
#   538,
#   51,
#   279,
#   11,
#   11,
#   1350,
#   1,
#   24,
#   9,
#   871,
#   1719,
#   221,
#   20629,
#   20630],
#  [141,
#   78,
#   14188,
#   1136,
#   19,
#   55,
#   10,
#   2618,
#   656,
#   2684,
#   2,
#   8229,
#   20631,
#   4,
#   1,
#   1960,
#   1466,
#   3,
#   11197,
#   4,
#   331,
#   66,
#   2846,
#   31,
#   3528,
#   8230,
#   3,
#   1,
#   9407,
#   2169,
#   9,
#   3828,
#   43,
#   15,
#   4440,
#   237,
#   13,
#   8,
#   271,
#   9408,
#   3050,
#   26,
#   3050,
#   4978,
#   504,
#   425],
#  [77,
#   387,
#   884,
#   22,
#   5,
#   265,
#   123,
#   1250,
#   2,
#   2117,
#   9409,
#   17,
#   29,
#   7348,
#   20632,
#   78,
#   37,
#   276,
#   17,
#   1073,
#   1123,
#   204,
#   8,
#   77,
#   551,
#   1159,
#   2,
#   483,
#   5,
#   518,
#   12,
#   1,
#   961,
#   3,
#   11198,
#   4979,
# ...
#   529,
#   3402,
#   25,
#   878,
#   78,
#   1,
#   284,
#   39,
#   16,
#   128,
#   2,
#   937,
#   11,
#   176,
#   1,
#   2516,
#   22,
#   6,
#   219,
#   1,
#   400,
#   1515,
#   1,
#   412,
#   34,
#   30,
#   268,
#   80,
#   80,
#   5,
#   284,
#   114,
#   17,
#   25,
#   46,
#   3,
#   1,
#   57,
#   864,
#   492,
#   34,
#   30,
#   121,
#   269,
#   864,
#   268,
#   80,
#   64,
#   30,
#   121,
#   269,
#   864,
#   12,
#   1,
#   508,
#   184,
#   3,
#   269,
#   864,
#   9,
#   6,
#   39,
#   80,
#   22,
#   6,
#   19,
#   742,
#   57,
#   1345,
#   410,
#   1266,
#   9,
#   6,
#   19,
#   1749,
#   92,
#   123,
#   4,
#   927,
#   95,
#   165,
#   6,
#   39,
#   144,
#   5,
#   184,
#   3,
#   1345,
#   6,
#   19,
#   742,
#   31,
#   411,
#   13,
#   173,
#   1216,
#   4,
#   5457,
#   327,
#   87,
#   16,
#   166,
#   46,
#   692,
#   145,
#   52,
#   19,
#   55,
#   927,
#   17,
#   1090,
#   15,
#   412,
#   12,
#   306,
#   108,
#   22,
#   1,
#   121,
#   8,
#   1670,
#   176,
#   5,
#   290,
#   200,
#   1178,
#   515,
#   30,
#   268,
#   80,
#   78,
#   1,
#   121,
#   45,
#   16,
#   166,
#   1765,
#   778,
#   145,
#   22,
#   6,
#   19,
#   53,
#   245,
#   49,
#   201,
#   95,
#   34,
#   1,
#   400,
#   269,
#   245,
#   27,
#   140,
#   6,
#   33,
#   6,
#   113,
#   2,
#   7609,
#   76,
#   3,
#   5471,
#   13,
#   423,
#   243],
#  [562, 101, 12, 91, 4847, 100, 91, 230],
#  [513, 38, 22380, 429, 3, 22381],
#  [7, 64, 6, 48, 2483, 776, 19, 21, 2483],
#  [1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604,
#   1773,
#   45,
#   612,
#   1449,
#   22,
#   6,
#   59,
#   825,
#   1,
#   1773,
#   6,
#   45,
#   1040,
#   6,
#   1659,
#   1604],
#  [626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414,
#   626,
#   396,
#   414],
#  [105,
#   7610,
#   18,
#   4580,
#   26,
#   1,
#   1359,
#   8,
#   1741,
#   368,
#   19,
#   372,
#   135,
#   3,
#   153,
#   6,
#   4287,
#   9,
#   52,
#   134,
#   2,
#   22382,
#   45,
#   233,
#   171,
#   4,
#   99,
#   1,
#   1312,
#   6,
#   88,
#   1,
#   151,
#   213,
#   4,
#   7,
#   219,
#   9,
#   401,
#   858,
#   101,
#   609],
#  [5472, 22383, 5143],
#  [11,
#   109,
#   1658,
#   26,
#   14,
#   10,
#   13,
#   590,
#   323,
#   1,
#   809,
#   115,
#   877,
#   402,
#   25,
#   14,
#   77,
#   101,
#   10,
#   13,
#   3474],
#  [224,
#   333,
#   22384,
#   4,
#   224,
#   2,
#   30,
#   140,
#   6,
#   12,
#   21,
#   348,
#   7,
#   231,
#   6,
#   48,
#   1,
#   191,
#   4,
#   877,
#   2,
#   640,
#   63,
#   18,
#   62,
#   122,
#   9,
#   6,
#   193,
#   144,
#   802,
#   1,
#   752,
#   1110,
#   3,
#   30,
#   1175,
#   73,
#   2,
#   72,
#   5,
#   27,
#   4,
#   73,
#   2,
#   1962,
#   85,
#   73,
#   2,
#   483,
#   21,
#   115,
#   24,
#   197,
#   1,
#   24,
#   2830,
#   22,
#   6,
#   528,
#   904,
#   3,
#   352,
#   7,
#   231,
#   6,
#   854,
#   143,
#   63,
#   4,
#   86,
#   5,
#   895,
#   49,
#   576,
#   21,
#   943,
#   15,
#   149,
#   122,
#   197,
#   516,
#   971,
#   13,
#   45,
#   815,
#   1434,
#   21,
#   603,
#   4,
#   1,
#   437,
#   22,
#   6,
#   134,
#   137,
#   340,
#   76,
#   30,
#   245,
#   201,
#   36,
#   15,
#   28,
#   38,
#   27,
#   25,
#   201,
#   21,
#   212,
#   15,
#   13,
#   27,
#   4,
#   78,
#   191,
#   137,
#   36,
#   154,
#   1,
#   212,
#   126,
#   224,
#   22385],
#  [243, 142, 9814, 6, 28, 666, 431, 231, 6, 295, 11],
#  [2505,
#   14977,
#   33,
#   6,
#   70,
#   9,
#   11,
#   45,
#   16,
#   540,
#   2,
#   1997,
#   53,
#   56,
#   77,
#   1809,
#   695,
#   4,
#   11,
#   130,
#   203,
#   162,
#   48,
#   139,
#   56,
#   39,
#   16,
#   185,
#   2,
#   11,
#   1,
#   10,
#   1514,
#   177,
#   8,
#   253,
#   1660,
#   569,
#   1,
#   184,
#   1,
#   1754,
#   14977,
#   493,
#   39,
#   16,
#   185,
#   2,
#   1,
#   57,
#   184,
#   37,
#   3413,
#   1,
#   3180,
#   762,
#   2574,
#   210],
#  [37,
#   21,
#   3669,
#   3043,
#   1512,
#   35,
#   17,
#   61,
#   167,
#   7611,
#   65,
#   18,
#   6,
#   2,
#   2519,
#   53,
#   226,
#   3,
#   13,
#   24,
#   21,
#   2232,
#   1008,
#   15,
#   4581,
#   112,
#   458,
#   4,
#   6296,
#   2,
#   13,
#   24,
#   8,
#   14978,
#   6,
#   18,
#   14,
#   1570,
#   20,
#   1,
#   275,
#   360,
#   21,
#   2638,
#   8,
#   14979,
#   31,
#   21,
#   3043,
#   1512,
#   4,
#   6,
#   19,
#   1113,
#   44,
#   406,
#   35,
#   1,
#   559,
#   3,
#   17,
#   10,
#   1,
#   1299,
#   3,
#   3606,
#   34,
#   959,
#   40,
#   18,
#   6,
#   168,
#   294,
#   63],
#  [25,
#   7,
#   104,
#   307,
#   237,
#   1,
#   3284,
#   37,
#   9,
#   11,
#   22386,
#   22387,
#   10,
#   5446,
#   86,
#   5473,
#   1,
#   14640,
#   8,
#   41,
#   67,
#   11,
#   8,
#   41,
#   11,
#   51,
#   1394,
#   2,
#   16,
#   10,
#   1,
#   954],
#  [346,
#   174,
#   11715,
#   1,
#   2960,
#   18,
#   42,
#   4716,
#   76,
#   34,
#   30,
#   73,
#   2,
#   965,
#   1392,
#   4,
#   2958,
#   3761,
#   17,
#   7,
#   292,
#   76,
#   1969,
#   84,
#   6,
#   296,
#   2,
#   473,
#   29,
#   24,
#   32,
#   378,
#   5,
#   2,
#   378,
#   592,
#   4,
#   378,
#   592,
#   253,
#   1241,
#   1,
#   1430,
#   45,
#   815,
#   299,
#   1,
#   132,
#   3,
#   378,
#   592,
#   12,
#   6,
#   84,
#   6,
#   473,
#   1,
#   24,
#   296,
#   2,
#   22388,
#   1,
#   392,
#   3,
#   3716,
#   6,
#   134,
#   2,
#   299,
#   4,
#   2247,
#   17,
#   615,
#   4,
#   2524,
#   122,
#   8,
#   46,
#   3,
#   1,
#   135,
#   14980,
#   3377,
#   10,
#   3221,
#   66,
#   77,
#   5,
#   101,
#   406,
#   2,
#   118,
#   10,
#   1,
#   473,
#   509,
#   9,
#   1,
#   473,
#   932,
#   16,
#   326,
#   381,
#   7,
#   23,
#   174,
#   3413,
#   6729,
#   4,
#   5,
#   105,
#   944,
#   240,
#   614,
#   2,
#   473,
#   11,
#   171,
#   216,
#   7,
#   23,
#   546,
#   15,
#   1,
#   174,
#   1283,
#   54,
#   5144,
#   10,
#   6729,
#   14592,
#   32,
#   30,
#   12,
#   5,
#   286,
#   1836,
#   394,
#   252,
#   296,
#   1,
#   138,
#   213,
#   34,
#   14981,
#   46,
#   291,
#   231,
#   13,
#   1720,
#   62,
#   22389],
#  [3113, 11410, 119, 125, 5120, 145, 4329, 2362, 13, 2199, 3762, 11716],
#  [988,
#   1053,
#   601,
#   178,
#   44,
#   422,
#   5,
#   173,
#   2,
#   1,
#   767,
#   318,
#   34,
#   1,
#   357,
#   3,
#   1,
#   24,
#   211,
#   56,
#   93,
#   330,
#   2184,
#   2265],
#  [7,
#   64,
#   505,
#   9815,
#   13,
#   17,
#   29,
#   312,
#   30,
#   1611,
#   2005,
#   2,
#   1145,
#   654,
#   544,
#   3666,
#   13,
#   109,
#   14,
#   764,
#   2,
#   1145,
#   30,
#   544,
#   552,
#   1,
#   544,
#   1354,
#   12,
#   1829,
#   12,
#   13,
#   24,
#   2,
#   4433,
#   6,
#   45,
#   134,
#   2,
#   19,
#   1129,
#   103,
#   32,
#   265,
#   739,
#   511,
#   110,
#   14982,
#   20,
#   1,
#   275,
#   609,
#   14983],
#  [77,
#   1,
#   22390,
#   22,
#   1256,
#   408,
#   95,
#   2,
#   1,
#   22391,
#   179,
#   78,
#   71,
#   2236,
#   718,
#   95,
#   90,
#   3924,
#   966],
#  [1377, 104, 6, 16, 56, 2661, 2711, 1054, 6219, 2188],
#  [1691,
#   28,
#   22392,
#   132,
#   82,
#   980,
#   1037,
#   22393,
#   1195,
#   4,
#   10,
#   849,
#   22394,
#   132,
#   82,
#   4,
#   1576,
#   76,
#   3,
#   849,
#   4,
#   1735,
#   9,
#   50,
#   182,
#   147,
#   1,
#   85,
#   50,
#   8,
#   1800,
#   54,
#   4074,
#   1,
#   3452,
#   10,
#   5,
#   1122,
#   914,
#   7,
#   69,
#   242,
#   2,
#   201,
#   26,
#   19,
#   6,
#   147,
#   1,
#   103,
#   2,
#   64,
#   1,
#   653,
#   397,
#   222,
#   31,
#   1,
#   148,
#   701,
#   2600,
#   2,
#   1,
#   8554,
#   1248,
#   3,
#   2045,
#   103,
#   12,
#   44,
#   1475,
#   961,
#   49,
#   367,
#   28,
#   1049,
#   4,
#   318,
#   36,
#   40,
#   23,
#   2045,
#   25,
#   76,
#   3,
#   849,
#   7,
#   69,
#   14,
#   2114,
#   2,
#   1424,
#   84,
#   7,
#   69,
#   254,
#   7,
#   19,
#   102,
#   5,
#   392,
#   3,
#   8555,
#   4,
#   3267,
#   79,
#   367,
#   1,
#   174,
#   4,
#   52,
#   82,
#   66,
#   7612,
#   4,
#   11133,
#   17,
#   7,
#   23,
#   6,
#   134,
#   2,
#   175,
#   259,
#   13,
#   202,
#   4,
#   1451,
#   15,
#   1,
#   561,
#   397,
#   691,
#   148,
#   17,
#   5,
#   2746,
#   8,
#   14248,
#   1120,
#   7,
#   69,
#   1,
#   51,
#   1,
#   273,
#   10,
#   5,
#   282,
#   466,
#   3,
#   2058,
#   220,
#   1564,
#   4,
#   9816,
#   9,
#   19,
#   4702,
#   60,
#   3272,
#   4,
#   2361,
#   245,
#   99,
#   136,
#   221,
#   6283,
#   7,
#   19,
#   66,
#   11717,
#   1635,
#   28,
#   1485,
#   350,
#   238,
#   2,
#   4848,
#   20,
#   62,
#   5737,
#   220,
#   10,
#   1,
#   228,
#   1,
#   2858,
#   4,
#   699,
#   4,
#   7,
#   23,
#   756,
#   31,
#   660,
#   9,
#   7,
#   23,
#   3047,
#   15,
#   242,
#   126,
#   12,
#   42,
#   1,
#   1268],
#  [450, 868, 21, 123],
#  [12,
#   2360,
#   4032,
#   649,
#   149,
#   3,
#   9,
#   1243,
#   47,
#   16,
#   10,
#   1,
#   24,
#   2908,
#   339,
#   13,
#   24,
#   8,
#   3338,
#   35,
#   1,
#   622,
#   3,
#   6297,
#   870,
#   554,
#   3322,
#   1054,
#   725,
#   178],
#  [426,
#   11718,
#   4,
#   8556,
#   744,
#   17,
#   2,
#   1,
#   57,
#   2222,
#   232,
#   36,
#   7,
#   3336,
#   5,
#   90,
#   117,
#   35,
#   1,
#   83,
#   7,
#   23,
#   86,
#   181,
#   12,
#   617,
#   778,
#   12,
#   826,
#   1393,
#   13,
#   208,
#   23,
#   3338,
#   1183,
#   2,
#   5,
#   38,
#   27,
#   9,
#   7,
#   182,
#   3292,
#   28,
#   3763,
#   38,
#   27,
#   4,
#   47,
#   14,
#   80,
#   22,
#   7,
#   104,
#   137,
#   11,
#   7,
#   47,
#   1407,
#   14,
#   2,
#   7613,
#   28,
#   3763,
#   464,
#   84,
#   7,
#   14984,
#   54,
#   407,
#   28,
#   3763,
#   1149,
#   17,
#   5,
#   1915,
#   7,
#   2575,
#   7,
#   23,
#   1417,
#   15,
#   17,
#   5854,
#   5145,
#   4,
#   507,
#   14,
#   289,
#   2,
#   2256,
#   1149,
#   29,
#   3763,
#   527,
#   470,
#   61,
#   446,
#   9,
#   44,
#   46,
#   47,
#   2256,
#   1149,
#   29,
#   3763,
#   141,
#   125,
#   18,
#   56,
#   535,
#   93,
#   5,
#   90,
#   117],
#  [21,
#   22395,
#   75,
#   18,
#   6,
#   289,
#   2,
#   2909,
#   30,
#   3,
#   1,
#   411,
#   122,
#   2961,
#   22396,
#   8557,
#   22397,
#   5410,
#   14985,
#   14986,
#   40,
#   8,
#   22398,
#   6,
#   1905,
#   1,
#   30,
#   40,
#   8,
#   21,
#   1125,
#   6781,
#   3475,
#   1691,
#   25,
#   22399,
#   7,
#   19,
#   1703,
#   7558,
#   20,
#   298,
#   3,
#   153,
#   1829,
#   141,
#   578,
#   4,
#   3182,
#   5425,
#   52,
#   61,
#   640,
#   4,
#   14,
#   16,
#   22400,
#   4076,
#   3,
#   28,
#   40,
#   14987,
#   14988,
#   5,
#   22401,
#   27,
#   54,
#   8,
#   14,
#   4076,
#   2994,
#   1440,
#   26,
#   65,
#   2734,
#   34,
#   13,
#   163,
#   14409,
#   7,
#   2785,
#   68,
#   8,
#   73,
#   109,
#   159,
#   233,
#   76,
#   3,
#   1,
#   14989,
#   145,
#   1285,
#   4,
#   1285,
#   3,
#   262,
#   2,
#   284,
#   4,
#   999,
#   42,
#   125,
#   122,
#   7,
#   51,
#   47,
#   48,
#   2,
#   64,
#   40,
#   21,
#   1501,
#   8,
#   11,
#   193,
#   9703,
#   36],
#  [6,
#   19,
#   182,
#   2044,
#   25,
#   55,
#   11719,
#   20,
#   5474,
#   14990,
#   2430,
#   6,
#   18,
#   7,
#   69,
#   865,
#   6,
#   2,
#   14,
#   14991,
#   20,
#   1,
#   24,
#   35,
#   5474,
#   14990,
#   6,
#   19,
#   44,
#   1622,
#   25,
#   3476,
#   2,
#   157,
#   604,
#   6,
#   18,
#   1697,
#   86,
#   5855,
#   37,
#   130,
#   6,
#   18,
#   14,
#   53,
#   648,
#   3,
#   1643,
#   15,
#   13,
#   1774,
#   554,
#   1930,
#   997,
#   1996,
#   725,
#   178],
#  [935,
#   624,
#   178,
#   3314,
#   71,
#   346,
#   593,
#   4691,
#   22402,
#   34,
#   1,
#   1357,
#   11720,
#   2841,
#   8,
#   9,
#   198,
#   24,
#   8,
#   1360,
#   790,
#   10,
#   13,
#   1645,
#   1626,
#   489,
#   997],
#  [510, 178, 700, 2265, 997, 935],
#  [13,
#   693,
#   23,
#   166,
#   31,
#   107,
#   883,
#   9817,
#   2,
#   1,
#   156,
#   9,
#   11,
#   1889,
#   395,
#   54,
#   8,
#   86,
#   6298,
#   1484,
#   141,
#   77,
#   5,
#   226,
#   3,
#   29,
#   2995,
#   395,
#   734,
#   31,
#   5,
#   546,
#   2973,
#   142,
#   1046,
#   9,
#   53,
#   22403,
#   2,
#   1,
#   395,
#   104,
#   16,
#   3015,
#   765,
#   1,
#   11721,
#   213,
#   2,
#   33,
#   10,
#   534,
#   2,
#   799,
#   22404,
#   9818,
#   281,
#   8,
#   2,
#   277,
#   11,
#   141,
#   6,
#   19,
#   1046,
#   2,
#   353,
#   13,
#   22405,
#   7,
#   69,
#   407,
#   20,
#   44,
#   1359,
#   26,
#   2,
#   589,
#   6,
#   2,
#   153,
#   10,
#   5,
#   191,
#   3,
#   1521,
#   34,
#   30,
#   3,
#   435,
#   6,
#   87,
#   221,
#   200,
#   2,
#   866,
#   4,
#   246,
#   21,
#   161,
#   395,
#   15,
#   1,
#   22406,
#   22407,
#   196,
#   142,
#   1046,
#   1,
#   272,
#   435,
#   3,
#   933,
#   8,
#   2,
#   2769,
#   1,
#   269,
#   15,
#   42,
#   4330,
#   395,
#   702,
#   4,
#   327,
#   1615,
#   20,
#   13,
#   24,
#   80,
#   3,
#   53,
#   3,
#   1,
#   285,
#   31,
#   1335,
#   57,
#   93,
#   1,
#   883,
#   186,
#   60,
#   1231,
#   8,
#   10,
#   760,
#   3,
#   939,
#   269,
#   1141,
#   4,
#   45,
#   16,
#   22408,
#   1045,
#   2,
#   1,
#   22409,
#   1623,
#   3582,
#   5020,
#   4,
#   42,
#   57,
#   4330,
#   3546],
#  [7,
#   682,
#   9,
#   159,
#   479,
#   1,
#   513,
#   2,
#   195,
#   3565,
#   24,
#   3,
#   14992,
#   22,
#   344,
#   249,
#   1092,
#   783,
#   15,
#   1,
#   272,
#   513,
#   5,
#   3339,
#   27,
#   193,
#   16,
#   5,
#   101,
#   1847,
#   2,
#   799,
#   29,
#   72,
#   325,
#   154,
#   888,
#   1,
#   3339,
#   7,
#   66,
#   4816,
#   5,
#   695,
#   4582,
#   3,
#   4194,
#   3222,
#   48,
#   22410,
#   22411,
#   22412,
#   22413,
#   5,
#   101,
#   4331,
#   3,
#   95,
#   18,
#   3339,
#   122,
#   37,
#   1,
#   3339,
#   27,
#   1425,
#   48,
#   5,
#   101,
#   1895,
#   63,
#   14992,
#   8,
#   168,
#   106,
#   120,
#   37,
#   1,
#   392,
#   3,
#   283,
#   8,
#   304,
#   168,
#   695,
#   9,
#   439,
#   11,
#   81,
#   56,
#   361,
#   9,
#   11,
#   39,
#   16,
#   292,
#   1039,
#   10,
#   112,
#   6863],
#  [9,
#   8,
#   10,
#   433,
#   28,
#   2118,
#   196,
#   7,
#   296,
#   2,
#   1361,
#   112,
#   548,
#   26,
#   9,
#   39,
#   81,
#   100,
#   15,
#   12,
#   37,
#   282,
#   38],
#  [5,
#   513,
#   1421,
#   1436,
#   2574,
#   230,
#   7,
#   168,
#   59,
#   70,
#   53,
#   942,
#   1,
#   2064,
#   18,
#   4105,
#   26,
#   78,
#   22,
#   50,
#   5135,
#   1,
#   544,
#   7614,
#   62,
#   291,
#   1,
#   1004,
#   334,
#   8,
#   168,
#   41,
#   2,
#   160,
#   20],
#  ...]

# %%
xtrain_pad
# Out:
# array([[   0,    0,    0, ..., 1502,   38, 6072],
#        [   0,    0,    0, ...,    3,  101,  548],
#        [   0,    0,    0, ...,  359,   11,   38],
#        ...,
#        [   0,    0,    0, ...,    4,   45, 1576],
#        [   0,    0,    0, ...,    9,   77, 5989],
#        [   0,    0,    0, ...,  166,  202,  514]])

# %%
word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'of': 3,
#  'and': 4,
#  'a': 5,
#  'you': 6,
#  'i': 7,
#  'is': 8,
#  'that': 9,
#  'in': 10,
#  'it': 11,
#  'for': 12,
#  'this': 13,
#  'not': 14,
#  'on': 15,
#  'be': 16,
#  'as': 17,
#  'are': 18,
#  'have': 19,
#  'with': 20,
#  'your': 21,
#  'if': 22,
#  'was': 23,
#  'article': 24,
#  'or': 25,
#  'but': 26,
#  'page': 27,
#  'my': 28,
#  'an': 29,
#  'wikipedia': 30,
#  'by': 31,
#  'from': 32,
#  'do': 33,
#  'at': 34,
#  'about': 35,
#  'me': 36,
#  'so': 37,
#  'talk': 38,
#  'can': 39,
#  'what': 40,
#  'there': 41,
#  'all': 42,
#  'has': 43,
#  'no': 44,
#  'will': 45,
#  'one': 46,
#  'would': 47,
#  'like': 48,
#  'please': 49,
#  'he': 50,
#  'just': 51,
#  'they': 52,
#  'any': 53,
#  'which': 54,
#  'been': 55,
#  'more': 56,
#  'other': 57,
#  'we': 58,
#  "don't": 59,
#  'his': 60,
#  'should': 61,
#  'some': 62,
#  'here': 63,
#  'see': 64,
#  'who': 65,
#  'also': 66,
#  'because': 67,
#  'know': 68,
#  'am': 69,
#  'think': 70,
#  "i'm": 71,
#  'edit': 72,
#  'how': 73,
#  'up': 74,
#  'why': 75,
#  'out': 76,
#  "it's": 77,
#  'then': 78,
#  'people': 79,
#  'use': 80,
#  'only': 81,
#  'were': 82,
#  'time': 83,
#  'when': 84,
#  'articles': 85,
#  'being': 86,
#  'may': 87,
#  'did': 88,
#  'thanks': 89,
#  'user': 90,
#  'now': 91,
#  'their': 92,
#  'than': 93,
#  'even': 94,
#  'them': 95,
#  'get': 96,
#  'fuck': 97,
#  'fish': 98,
#  'make': 99,
#  'go': 100,
#  'good': 101,
#  'had': 102,
#  'information': 103,
#  'could': 104,
#  'well': 105,
#  'very': 106,
#  'its': 107,
#  'deletion': 108,
#  'does': 109,
#  'sources': 110,
#  'balls': 111,
#  'wp': 112,
#  'want': 113,
#  'such': 114,
#  'first': 115,
#  'way': 116,
#  'name': 117,
#  'say': 118,
#  'made': 119,
#  'new': 120,
#  'image': 121,
#  'pages': 122,
#  'source': 123,
#  'going': 124,
#  'these': 125,
#  'again': 126,
#  'ass': 127,
#  'used': 128,
#  'where': 129,
#  'really': 130,
#  'section': 131,
#  'edits': 132,
#  'sex': 133,
#  'need': 134,
#  'most': 135,
#  'many': 136,
#  'help': 137,
#  'same': 138,
#  'much': 139,
#  'thank': 140,
#  'since': 141,
#  "i've": 142,
#  'editing': 143,
#  'find': 144,
#  'after': 145,
#  'yourself': 146,
#  'read': 147,
#  'wiki': 148,
#  'discussion': 149,
#  'into': 150,
#  'right': 151,
#  'hate': 152,
#  'those': 153,
#  'before': 154,
#  'said': 155,
#  'fact': 156,
#  'him': 157,
#  'two': 158,
#  'someone': 159,
#  'work': 160,
#  'own': 161,
#  'look': 162,
#  'point': 163,
#  'something': 164,
#  'too': 165,
#  'deleted': 166,
#  'take': 167,
#  'still': 168,
#  'over': 169,
#  'add': 170,
#  'back': 171,
#  'her': 172,
#  'link': 173,
#  'history': 174,
#  'stop': 175,
#  'under': 176,
#  'content': 177,
#  'utc': 178,
#  'u': 179,
#  '1': 180,
#  'blocked': 181,
#  'never': 182,
#  'case': 183,
#  'list': 184,
#  'added': 185,
#  'without': 186,
#  "you're": 187,
#  'comment': 188,
#  '2': 189,
#  'removed': 190,
#  'place': 191,
#  'editors': 192,
#  'might': 193,
#  'better': 194,
#  'another': 195,
#  'however': 196,
#  'using': 197,
#  'our': 198,
#  'note': 199,
#  'free': 200,
#  'ask': 201,
#  'personal': 202,
#  "doesn't": 203,
#  'she': 204,
#  'done': 205,
#  'http': 206,
#  'reason': 207,
#  'block': 208,
#  'put': 209,
#  'anything': 210,
#  "that's": 211,
#  'question': 212,
#  'thing': 213,
#  'sure': 214,
#  'person': 215,
#  'while': 216,
#  'things': 217,
#  'off': 218,
#  'believe': 219,
#  'both': 220,
#  'feel': 221,
#  'vandalism': 222,
#  'policy': 223,
#  'welcome': 224,
#  'actually': 225,
#  'part': 226,
#  'seems': 227,
#  'us': 228,
#  'nigger': 229,
#  'though': 230,
#  'hope': 231,
#  'against': 232,
#  'come': 233,
#  'problem': 234,
#  'com': 235,
#  "didn't": 236,
#  'change': 237,
#  'comments': 238,
#  "can't": 239,
#  'editor': 240,
#  'world': 241,
#  'sorry': 242,
#  'hi': 243,
#  'life': 244,
#  'questions': 245,
#  'post': 246,
#  '3': 247,
#  'reference': 248,
#  'different': 249,
#  'little': 250,
#  'links': 251,
#  "i'll": 252,
#  'already': 253,
#  'wrong': 254,
#  'understand': 255,
#  'years': 256,
#  'oh': 257,
#  'give': 258,
#  'making': 259,
#  'others': 260,
#  'agree': 261,
#  'nothing': 262,
#  'keep': 263,
#  'anyone': 264,
#  'reliable': 265,
#  'must': 266,
#  'english': 267,
#  'fair': 268,
#  'copyright': 269,
#  'mean': 270,
#  'rather': 271,
#  'best': 272,
#  'last': 273,
#  'issue': 274,
#  'subject': 275,
#  'far': 276,
#  'remove': 277,
#  "isn't": 278,
#  'leave': 279,
#  'write': 280,
#  'etc': 281,
#  'long': 282,
#  'references': 283,
#  'tag': 284,
#  'above': 285,
#  'few': 286,
#  'e': 287,
#  'says': 288,
#  'trying': 289,
#  'non': 290,
#  'day': 291,
#  'found': 292,
#  'word': 293,
#  'doing': 294,
#  'got': 295,
#  'try': 296,
#  'evidence': 297,
#  'either': 298,
#  'delete': 299,
#  'sexsex': 300,
#  'every': 301,
#  'yes': 302,
#  'example': 303,
#  'probably': 304,
#  'through': 305,
#  'speedy': 306,
#  'simply': 307,
#  'between': 308,
#  'least': 309,
#  'text': 310,
#  'called': 311,
#  'encyclopedia': 312,
#  'great': 313,
#  'site': 314,
#  'users': 315,
#  'having': 316,
#  'book': 317,
#  'show': 318,
#  'based': 319,
#  'around': 320,
#  'original': 321,
#  'yet': 322,
#  'let': 323,
#  'request': 324,
#  'war': 325,
#  'reverted': 326,
#  'images': 327,
#  'opinion': 328,
#  'else': 329,
#  'enough': 330,
#  'perhaps': 331,
#  'created': 332,
#  'hello': 333,
#  'material': 334,
#  'down': 335,
#  'www': 336,
#  'ever': 337,
#  'account': 338,
#  'state': 339,
#  'check': 340,
#  'version': 341,
#  'view': 342,
#  'adding': 343,
#  'clearly': 344,
#  'states': 345,
#  're': 346,
#  'clear': 347,
#  'contributions': 348,
#  'message': 349,
#  'written': 350,
#  'bot': 351,
#  'style': 352,
#  'continue': 353,
#  'further': 354,
#  'consensus': 355,
#  'bit': 356,
#  'top': 357,
#  'needs': 358,
#  'support': 359,
#  'matter': 360,
#  'important': 361,
#  'ip': 362,
#  '5': 363,
#  'saying': 364,
#  'times': 365,
#  'fucking': 366,
#  'review': 367,
#  "i'd": 368,
#  'given': 369,
#  'website': 370,
#  'tell': 371,
#  'thought': 372,
#  'statement': 373,
#  'language': 374,
#  's': 375,
#  '—': 376,
#  'bad': 377,
#  'title': 378,
#  'true': 379,
#  '4': 380,
#  'once': 381,
#  'each': 382,
#  'real': 383,
#  'lot': 384,
#  'several': 385,
#  'term': 386,
#  'quite': 387,
#  'old': 388,
#  'instead': 389,
#  'claim': 390,
#  'until': 391,
#  'number': 392,
#  'revert': 393,
#  'maybe': 394,
#  'research': 395,
#  '8': 396,
#  'facts': 397,
#  'mention': 398,
#  'year': 399,
#  'media': 400,
#  'always': 401,
#  'whether': 402,
#  'three': 403,
#  'template': 404,
#  'notable': 405,
#  'idea': 406,
#  'left': 407,
#  'changes': 408,
#  'correct': 409,
#  'consider': 410,
#  'following': 411,
#  'criteria': 412,
#  'useless': 413,
#  'd': 414,
#  'words': 415,
#  'pov': 416,
#  'means': 417,
#  'considered': 418,
#  'seem': 419,
#  'main': 420,
#  'fan': 421,
#  "there's": 422,
#  'notice': 423,
#  'call': 424,
#  'c': 425,
#  'cannot': 426,
#  'admin': 427,
#  'american': 428,
#  'school': 429,
#  'homeland': 430,
#  'address': 431,
#  'second': 432,
#  'general': 433,
#  '•': 434,
#  'course': 435,
#  'possible': 436,
#  'date': 437,
#  'guidelines': 438,
#  'makes': 439,
#  'current': 440,
#  'include': 441,
#  'getting': 442,
#  'securityfuck': 443,
#  'tommy2010': 444,
#  'including': 445,
#  'suggest': 446,
#  'group': 447,
#  'cool': 448,
#  'regarding': 449,
#  'man': 450,
#  'attack': 451,
#  'interest': 452,
#  'issues': 453,
#  'looking': 454,
#  'specific': 455,
#  'less': 456,
#  'end': 457,
#  'rules': 458,
#  'seen': 459,
#  'recent': 460,
#  'explain': 461,
#  'mentioned': 462,
#  'dont': 463,
#  'later': 464,
#  'whole': 465,
#  'line': 466,
#  'bob': 467,
#  'answer': 468,
#  'relevant': 469,
#  'sense': 470,
#  'ok': 471,
#  'days': 472,
#  'move': 473,
#  'kind': 474,
#  'although': 475,
#  'known': 476,
#  'project': 477,
#  'cunt': 478,
#  'changed': 479,
#  'care': 480,
#  'jpg': 481,
#  'start': 482,
#  'create': 483,
#  'org': 484,
#  'claims': 485,
#  'happy': 486,
#  'myself': 487,
#  'anyway': 488,
#  '10': 489,
#  'p': 490,
#  'news': 491,
#  'listed': 492,
#  'info': 493,
#  'provide': 494,
#  'currently': 495,
#  'topic': 496,
#  'next': 497,
#  'atheist': 498,
#  'taken': 499,
#  'single': 500,
#  'anti': 501,
#  'stuff': 502,
#  "wikipedia's": 503,
#  't': 504,
#  "you've": 505,
#  'big': 506,
#  'certainly': 507,
#  'full': 508,
#  'summary': 509,
#  '2005': 510,
#  'party': 511,
#  'books': 512,
#  'redirect': 513,
#  'attacks': 514,
#  'per': 515,
#  'four': 516,
#  'related': 517,
#  'category': 518,
#  'sentence': 519,
#  '1967': 520,
#  'saget': 521,
#  'warning': 522,
#  'political': 523,
#  'talking': 524,
#  'file': 525,
#  'interested': 526,
#  'common': 527,
#  'wish': 528,
#  'picture': 529,
#  'knowledge': 530,
#  'country': 531,
#  'according': 532,
#  'self': 533,
#  'order': 534,
#  'public': 535,
#  'nor': 536,
#  'appears': 537,
#  'mind': 538,
#  'writing': 539,
#  'able': 540,
#  'love': 541,
#  'hey': 542,
#  'truth': 543,
#  'notability': 544,
#  'lead': 545,
#  'working': 546,
#  'licker': 547,
#  'faith': 548,
#  'especially': 549,
#  'names': 550,
#  'completely': 551,
#  'music': 552,
#  'web': 553,
#  '20': 554,
#  'appropriate': 555,
#  'god': 556,
#  'discuss': 557,
#  'started': 558,
#  'position': 559,
#  'future': 560,
#  'published': 561,
#  'looks': 562,
#  '6': 563,
#  'city': 564,
#  'major': 565,
#  'proposed': 566,
#  'included': 567,
#  'ago': 568,
#  'within': 569,
#  'official': 570,
#  'during': 571,
#  'response': 572,
#  'away': 573,
#  'neutral': 574,
#  'everything': 575,
#  'sign': 576,
#  'en': 577,
#  '2007': 578,
#  'wanted': 579,
#  'nice': 580,
#  'removing': 581,
#  'wrote': 582,
#  'united': 583,
#  'false': 584,
#  'quote': 585,
#  'conflict': 586,
#  'community': 587,
#  'similar': 588,
#  'report': 589,
#  'form': 590,
#  'learn': 591,
#  'b': 592,
#  'reading': 593,
#  '0': 594,
#  'asked': 595,
#  'rule': 596,
#  'policies': 597,
#  'game': 598,
#  'therefore': 599,
#  '11': 600,
#  '2006': 601,
#  '9': 602,
#  'username': 603,
#  'unless': 604,
#  'npov': 605,
#  'today': 606,
#  'whatever': 607,
#  'side': 608,
#  'cheers': 609,
#  'pretty': 610,
#  'government': 611,
#  'live': 612,
#  'system': 613,
#  'tried': 614,
#  'deleting': 615,
#  'itself': 616,
#  '24': 617,
#  'placed': 618,
#  'hard': 619,
#  "wasn't": 620,
#  'came': 621,
#  'theory': 622,
#  'dispute': 623,
#  '2008': 624,
#  'sourced': 625,
#  'penis': 626,
#  'paragraph': 627,
#  'reply': 628,
#  'present': 629,
#  'process': 630,
#  'obviously': 631,
#  'posted': 632,
#  'involved': 633,
#  '7': 634,
#  'high': 635,
#  '2010': 636,
#  'google': 637,
#  "won't": 638,
#  'past': 639,
#  'stay': 640,
#  'reverting': 641,
#  'taking': 642,
#  'mud': 643,
#  'useful': 644,
#  'explanation': 645,
#  'edited': 646,
#  'play': 647,
#  'sort': 648,
#  'reasons': 649,
#  'below': 650,
#  'contribs': 651,
#  'open': 652,
#  'actual': 653,
#  'certain': 654,
#  'improve': 655,
#  'due': 656,
#  'views': 657,
#  'exactly': 658,
#  'short': 659,
#  'everyone': 660,
#  'needed': 661,
#  '12': 662,
#  '100': 663,
#  'guess': 664,
#  'along': 665,
#  'email': 666,
#  'sandbox': 667,
#  'become': 668,
#  'almost': 669,
#  'murder': 670,
#  'entire': 671,
#  'company': 672,
#  'problems': 673,
#  'interesting': 674,
#  'remember': 675,
#  'various': 676,
#  'de': 677,
#  'obvious': 678,
#  'band': 679,
#  'banned': 680,
#  'appreciate': 681,
#  'noticed': 682,
#  'admins': 683,
#  'fun': 684,
#  'dick': 685,
#  'internet': 686,
#  'w': 687,
#  'stated': 688,
#  'citation': 689,
#  'guy': 690,
#  'otherwise': 691,
#  'week': 692,
#  'entry': 693,
#  'status': 694,
#  'small': 695,
#  'cited': 696,
#  'argument': 697,
#  'search': 698,
#  'canada': 699,
#  '15': 700,
#  'definition': 701,
#  'statements': 702,
#  'took': 703,
#  'alone': 704,
#  'went': 705,
#  'story': 706,
#  'law': 707,
#  'terms': 708,
#  'works': 709,
#  'follow': 710,
#  'themselves': 711,
#  'provided': 712,
#  '\xa0': 713,
#  "haven't": 714,
#  'often': 715,
#  'color': 716,
#  'points': 717,
#  'kill': 718,
#  'likely': 719,
#  'death': 720,
#  'type': 721,
#  'stupid': 722,
#  'shit': 723,
#  'yeah': 724,
#  '2004': 725,
#  'saw': 726,
#  'science': 727,
#  'cite': 728,
#  'soon': 729,
#  'g': 730,
#  'addition': 731,
#  'faggot': 732,
#  'proper': 733,
#  'piece': 734,
#  'series': 735,
#  'set': 736,
#  'national': 737,
#  'mr': 738,
#  'third': 739,
#  'king': 740,
#  'accurate': 741,
#  'uploaded': 742,
#  'indeed': 743,
#  'actions': 744,
#  'british': 745,
#  'shows': 746,
#  'disagree': 747,
#  'generally': 748,
#  'vandalize': 749,
#  'allowed': 750,
#  'power': 751,
#  'five': 752,
#  'calling': 753,
#  'rights': 754,
#  'regards': 755,
#  'told': 756,
#  'area': 757,
#  'human': 758,
#  'particular': 759,
#  'violation': 760,
#  'german': 761,
#  "wouldn't": 762,
#  'm': 763,
#  'appear': 764,
#  'thus': 765,
#  'film': 766,
#  'tv': 767,
#  'accept': 768,
#  'himself': 769,
#  'external': 770,
#  'contributing': 771,
#  'assume': 772,
#  'background': 773,
#  'university': 774,
#  'india': 775,
#  'fine': 776,
#  'moved': 777,
#  'hours': 778,
#  'details': 779,
#  '–': 780,
#  'black': 781,
#  'valid': 782,
#  'exist': 783,
#  'test': 784,
#  'guys': 785,
#  'cause': 786,
#  'class': 787,
#  'wikiproject': 788,
#  'attention': 789,
#  'nonsense': 790,
#  'gay': 791,
#  'legal': 792,
#  'contact': 793,
#  'administrator': 794,
#  'description': 795,
#  '16': 796,
#  'together': 797,
#  'upon': 798,
#  'avoid': 799,
#  'culture': 800,
#  'outside': 801,
#  'helpful': 802,
#  'hand': 803,
#  'loser': 804,
#  'job': 805,
#  'goes': 806,
#  'attempt': 807,
#  'members': 808,
#  'debate': 809,
#  "let's": 810,
#  '19': 811,
#  'v': 812,
#  "he's": 813,
#  'greek': 814,
#  'automatically': 815,
#  'seriously': 816,
#  'head': 817,
#  "aren't": 818,
#  "article's": 819,
#  '000': 820,
#  'aware': 821,
#  'computer': 822,
#  '2009': 823,
#  'period': 824,
#  'respect': 825,
#  'multiple': 826,
#  'lack': 827,
#  'ones': 828,
#  'bias': 829,
#  'recently': 830,
#  'result': 831,
#  'personally': 832,
#  '23': 833,
#  'living': 834,
#  'citations': 835,
#  'r': 836,
#  'unblock': 837,
#  'level': 838,
#  'sites': 839,
#  'july': 840,
#  '22': 841,
#  'french': 842,
#  'barnstar': 843,
#  'worked': 844,
#  'white': 845,
#  '14': 846,
#  'south': 847,
#  'im': 848,
#  'context': 849,
#  'family': 850,
#  'previous': 851,
#  'online': 852,
#  'john': 853,
#  'enjoy': 854,
#  'meant': 855,
#  'happened': 856,
#  'serious': 857,
#  'comes': 858,
#  'north': 859,
#  'august': 860,
#  'data': 861,
#  'entirely': 862,
#  'incorrect': 863,
#  'tags': 864,
#  'asking': 865,
#  'complete': 866,
#  'gets': 867,
#  "what's": 868,
#  'criticism': 869,
#  '18': 870,
#  'modern': 871,
#  'watching': 872,
#  'team': 873,
#  'historical': 874,
#  'uk': 875,
#  'speak': 876,
#  'decide': 877,
#  'video': 878,
#  'earlier': 879,
#  'uses': 880,
#  'available': 881,
#  'sock': 882,
#  'author': 883,
#  'simple': 884,
#  'changing': 885,
#  "they're": 886,
#  'children': 887,
#  'creating': 888,
#  'blocking': 889,
#  'f': 890,
#  'close': 891,
#  'specifically': 892,
#  'standard': 893,
#  '30': 894,
#  'wikipedian': 895,
#  'months': 896,
#  'refer': 897,
#  'heard': 898,
#  'al': 899,
#  'run': 900,
#  'doubt': 901,
#  'accepted': 902,
#  'copy': 903,
#  'manual': 904,
#  'supposed': 905,
#  'apparently': 906,
#  'jewish': 907,
#  'none': 908,
#  'album': 909,
#  'arguments': 910,
#  'explaining': 911,
#  'ban': 912,
#  'missing': 913,
#  'light': 914,
#  'fail': 915,
#  'biased': 916,
#  'financial': 917,
#  'figure': 918,
#  'study': 919,
#  'press': 920,
#  'bastard': 921,
#  'face': 922,
#  'understanding': 923,
#  'sometimes': 924,
#  "you'll": 925,
#  'html': 926,
#  'tagged': 927,
#  'coming': 928,
#  'events': 929,
#  'deal': 930,
#  'putting': 931,
#  "shouldn't": 932,
#  'action': 933,
#  '13': 934,
#  'december': 935,
#  'special': 936,
#  'release': 937,
#  'homo': 938,
#  'international': 939,
#  'sections': 940,
#  'shall': 941,
#  'o': 942,
#  'messages': 943,
#  'meaning': 944,
#  'longer': 945,
#  'contest': 946,
#  'rationale': 947,
#  'cities': 948,
#  'necessary': 949,
#  'member': 950,
#  'america': 951,
#  'warring': 952,
#  'act': 953,
#  'photo': 954,
#  'academic': 955,
#  'shut': 956,
#  'fucker': 957,
#  'proof': 958,
#  'large': 959,
#  'prominent': 960,
#  'purpose': 961,
#  'rest': 962,
#  'dead': 963,
#  'march': 964,
#  'fix': 965,
#  'business': 966,
#  'border': 967,
#  'vote': 968,
#  'christian': 969,
#  'allow': 970,
#  'tildes': 971,
#  'except': 972,
#  'x': 973,
#  '21': 974,
#  'expect': 975,
#  'western': 976,
#  'century': 977,
#  'force': 978,
#  'population': 979,
#  'factual': 980,
#  'june': 981,
#  'hell': 982,
#  'readers': 983,
#  'pro': 984,
#  'civil': 985,
#  'home': 986,
#  "'": 987,
#  '25': 988,
#  'lol': 989,
#  'age': 990,
#  'born': 991,
#  'nobody': 992,
#  'space': 993,
#  'minor': 994,
#  'lists': 995,
#  'situation': 996,
#  '17': 997,
#  'bring': 998,
#  'afd': 999,
#  'wants': 1000,
#  ...}

# %%
# %%time
with strategy.scope():
    # A simpleRNN without any pretrained embeddings and one dense layer
    model = Sequential()
    model.add(Embedding(len(word_index) + 1,
                     300,
                     input_length=max_len)) # model.add 라고 하면 새로운 은닉층이 만들어진다. model.add가 3개 있으므로 3개의 층을 가진 모델이다.
                     # Embedding(입력개수, 출력개수, 단어 시퀀수 수)  
    model.add(SimpleRNN(100))
    model.add(Dense(1, activation='sigmoid')) # 이 맨 마지막층은 결과를 출력 하는 층이다.
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # model.compile 부분은 앞서 지정한 모델이 효과적으로 구현될 수 있게 여러 가지 환경을 설정해 주면서 컴파일하는 부분
    # 어떤 오차 함수를 (loss) 사용할지를 정해야 한다. 그다음 최적화 함수도 정의한다.
    # 마지막으로 metrics() 함수는 모델이 컴파일될 때 모델 수행 결과를 나타내게끔 설정하는 부분
    
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1500, 300)         13049100
#
#  simple_rnn (SimpleRNN)      (None, 100)               40100
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 13,089,301
# Trainable params: 13,089,301
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: total: 1.36 s
# Wall time: 491 ms

# %%
# 위의 결과 Output Shape (batch_size, units())

# %%
# 모델 학습

# %%
model.fit(xtrain_pad, ytrain, epochs=5, batch_size=64*strategy.num_replicas_in_sync) #Multiplying by Strategy to run on TPU's
# Out:
# Epoch 1/5
# 150/150 [==============================] - 269s 2s/step - loss: 0.3108 - accuracy: 0.8989
# Epoch 2/5
# 150/150 [==============================] - 266s 2s/step - loss: 0.2924 - accuracy: 0.8757
# Epoch 3/5
# 150/150 [==============================] - 269s 2s/step - loss: 0.0893 - accuracy: 0.9709
# Epoch 4/5
# 150/150 [==============================] - 271s 2s/step - loss: 0.0360 - accuracy: 0.9902
# Epoch 5/5
# 150/150 [==============================] - 278s 2s/step - loss: 0.0123 - accuracy: 0.9980

# %%
scores = model.predict(xvalid_pad)
print("Auc: %.2f%%" % (roc_auc(scores,yvalid)))
# Out:
# 76/76 [==============================] - 35s 452ms/step
# Auc: 0.79%

# %%
scores_model = []
scores_model.append({'Model': 'SimpleRNN','AUC_Score': roc_auc(scores,yvalid)})
scores_model
# Out:
# [{'Model': 'SimpleRNN', 'AUC_Score': 0.7861227401124219}]

# %%
# 훈련 데이터가 적은 상황이라면 케라스의 Embedding()으로 해당 문제를 풀기에 최적화 된 임베딩 벡터값을 얻는 것이 쉽지 않다. 
# 이 경우 해당 문제에 특화된 것은 아니지만 보다 많은 훈련 데이터로 이미 Word2Vec이나 GloVe, fasttext 등으로 학습되어져 있는 임베딩 벡터들을 사용하는 것이 성능의 개선을 가져올 수 있습니다

# %%
# load the GloVe vectors in a dictionary:

embeddings_index = {}
f = open('E:/Kaggle_Practice/Deep Learning For NLP_Zero To Transformers and BERT/glove.840B.300d.txt','r',encoding='utf-8')
for line in tqdm(f):
    values = line.split(' ')
    word = values[0]
    coefs = np.asarray([float(val) for val in values[1:]])
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# 2196018it [05:04, 7212.04it/s]
# Found 2196017 word vectors.

# %% [markdown]
# ## LSTM

# %%
# Simple RNN's were certainly better than classical ML algorithms and gave state of the art results, but it failed to capture long term dependencies that is present in sentences . 
# So in 1998-99 LSTM's were introduced to counter to these drawbacks.
